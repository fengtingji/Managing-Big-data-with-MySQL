# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql use dognitiondb
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %%
# %%sql
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# Out:
# 40 rows affected.
# [('1 vs 1 Game', Decimal('3.9206')),
#  ('3 vs 1 Game', Decimal('4.2857')),
#  ('5 vs 1 Game', Decimal('3.9272')),
#  ('Arm Pointing', Decimal('4.2153')),
#  ('Cover Your Eyes', Decimal('2.6741')),
#  ('Delayed Cup Game', Decimal('3.3514')),
#  ('Different Perspective', Decimal('2.7647')),
#  ('Expression Game', Decimal('4.0000')),
#  ('Eye Contact Game', Decimal('2.9372')),
#  ('Eye Contact Warm-up', Decimal('0.9632')),
#  ('Foot Pointing', Decimal('4.0093')),
#  ('Impossible Task Game', Decimal('3.0965')),
#  ('Impossible Task Warm-up', Decimal('0.2174')),
#  ('Inferential Reasoning Game', Decimal('4.5223')),
#  ('Inferential Reasoning Warm-up', Decimal('4.3066')),
#  ('Memory versus Pointing', Decimal('3.5584')),
#  ('Memory versus Smell', Decimal('4.2623')),
#  ('Navigation Game', Decimal('2.9841')),
#  ('Navigation Learning', Decimal('2.0303')),
#  ('Navigation Warm-up', Decimal('1.9805')),
#  ('Numerosity Warm-Up', Decimal('2.6173')),
#  ('One Cup Warm-up', Decimal('1.3693')),
#  ('Physical Reasoning Game', Decimal('3.8492')),
#  ('Physical Reasoning Warm-up', Decimal('1.6625')),
#  ('Self Control Game', Decimal('3.8519')),
#  ('Shaker Game', Decimal('4.6667')),
#  ('Shaker Warm-Up', Decimal('2.1818')),
#  ('Shared Perspective', Decimal('3.2778')),
#  ('Slide', Decimal('4.5111')),
#  ('Smell Game', Decimal('4.2857')),
#  ('Stair Game', Decimal('4.2857')),
#  ('Switch', Decimal('5.5676')),
#  ('Treat Warm-up', Decimal('0.7909')),
#  ('Turn Your Back', Decimal('3.1293')),
#  ('Two Cup Warm-up', Decimal('1.6737')),
#  ('Warm-Up', Decimal('1.2020')),
#  ('Watching', Decimal('2.4594')),
#  ('Watching - Part 2', Decimal('2.6570')),
#  ('Yawn Game', Decimal('2.8477')),
#  ('Yawn Warm-up', Decimal('2.0035'))]

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34),
#  ('3 vs 1 Game', 4, 16),
#  ('3 vs 1 Game', 5, 34),
#  ('3 vs 1 Game', 6, 42),
#  ('3 vs 1 Game', 7, 37),
#  ('3 vs 1 Game', 8, 23),
#  ('3 vs 1 Game', 9, 24),
#  ('3 vs 1 Game', 10, 28),
#  ('3 vs 1 Game', 11, 22),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 1, 59),
#  ('5 vs 1 Game', 2, 54),
#  ('5 vs 1 Game', 3, 57),
#  ('5 vs 1 Game', 4, 29),
#  ('5 vs 1 Game', 5, 50),
#  ('5 vs 1 Game', 6, 61),
#  ('5 vs 1 Game', 7, 69),
#  ('5 vs 1 Game', 8, 38),
#  ('5 vs 1 Game', 9, 50),
#  ('5 vs 1 Game', 10, 54),
#  ('5 vs 1 Game', 11, 40),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 1, 622),
#  ('Arm Pointing', 2, 498),
#  ('Arm Pointing', 3, 507),
#  ('Arm Pointing', 4, 381),
#  ('Arm Pointing', 5, 1149),
#  ('Arm Pointing', 6, 1424),
#  ('Arm Pointing', 7, 913),
#  ('Arm Pointing', 8, 779),
#  ('Arm Pointing', 9, 1243),
#  ('Arm Pointing', 10, 2535),
#  ('Arm Pointing', 11, 735),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 1, 452),
#  ('Cover Your Eyes', 2, 373),
#  ('Cover Your Eyes', 3, 416),
#  ('Cover Your Eyes', 4, 291),
#  ('Cover Your Eyes', 5, 753),
#  ('Cover Your Eyes', 6, 767),
#  ('Cover Your Eyes', 7, 521),
#  ('Cover Your Eyes', 8, 408),
#  ('Cover Your Eyes', 9, 574),
#  ('Cover Your Eyes', 10, 1653),
#  ('Cover Your Eyes', 11, 595),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 1, 356),
#  ('Delayed Cup Game', 2, 319),
#  ('Delayed Cup Game', 3, 350),
#  ('Delayed Cup Game', 4, 256),
#  ('Delayed Cup Game', 5, 539),
#  ('Delayed Cup Game', 6, 525),
#  ('Delayed Cup Game', 7, 407),
#  ('Delayed Cup Game', 8, 355),
#  ('Delayed Cup Game', 9, 424),
#  ('Delayed Cup Game', 10, 1019),
#  ('Delayed Cup Game', 11, 422),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 1, 2),
#  ('Different Perspective', 2, 3),
#  ('Different Perspective', 3, 4),
#  ('Different Perspective', 4, 8),
#  ('Different Perspective', 5, 12),
#  ('Different Perspective', 6, 11),
#  ('Different Perspective', 7, 8),
#  ('Different Perspective', 8, 10),
#  ('Different Perspective', 9, 12),
#  ('Different Perspective', 10, 4),
#  ('Different Perspective', 11, 6),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 1, 6),
#  ('Expression Game', 2, 9),
#  ('Expression Game', 3, 12),
#  ('Expression Game', 4, 10),
#  ('Expression Game', 5, 9),
#  ('Expression Game', 6, 11),
#  ('Expression Game', 7, 12),
#  ('Expression Game', 8, 11),
#  ('Expression Game', 9, 17),
#  ('Expression Game', 10, 3),
#  ('Expression Game', 11, 11),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 1, 506),
#  ('Foot Pointing', 2, 433),
#  ('Foot Pointing', 3, 477),
#  ('Foot Pointing', 4, 339),
#  ('Foot Pointing', 5, 926),
#  ('Foot Pointing', 6, 1125),
#  ('Foot Pointing', 7, 759),
#  ('Foot Pointing', 8, 653),
#  ('Foot Pointing', 9, 992),
#  ('Foot Pointing', 10, 2290),
#  ('Foot Pointing', 11, 685),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 1, 465),
#  ('Memory versus Smell', 2, 374),
#  ('Memory versus Smell', 3, 382),
#  ('Memory versus Smell', 4, 280),
#  ('Memory versus Smell', 5, 667),
#  ('Memory versus Smell', 6, 666),
#  ('Memory versus Smell', 7, 491),
#  ('Memory versus Smell', 8, 402),
#  ('Memory versus Smell', 9, 529),
#  ('Memory versus Smell', 10, 1111),
#  ('Memory versus Smell', 11, 444),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 1, 57),
#  ('Navigation Game', 2, 41),
#  ('Navigation Game', 3, 47),
#  ('Navigation Game', 4, 41),
#  ('Navigation Game', 5, 336),
#  ('Navigation Game', 6, 81),
#  ('Navigation Game', 7, 70),
#  ('Navigation Game', 8, 41),
#  ('Navigation Game', 9, 52),
#  ('Navigation Game', 10, 69),
#  ('Navigation Game', 11, 47),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 1, 62),
#  ('Navigation Warm-up', 2, 43),
#  ('Navigation Warm-up', 3, 50),
#  ('Navigation Warm-up', 4, 42),
#  ('Navigation Warm-up', 5, 625),
#  ('Navigation Warm-up', 6, 114),
#  ('Navigation Warm-up', 7, 88),
#  ('Navigation Warm-up', 8, 40),
#  ('Navigation Warm-up', 9, 58),
#  ('Navigation Warm-up', 10, 76),
#  ('Navigation Warm-up', 11, 52),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 1, 36),
#  ('Numerosity Warm-Up', 2, 28),
#  ('Numerosity Warm-Up', 3, 35),
#  ('Numerosity Warm-Up', 4, 17),
#  ('Numerosity Warm-Up', 5, 37),
#  ('Numerosity Warm-Up', 6, 44),
#  ('Numerosity Warm-Up', 7, 37),
#  ('Numerosity Warm-Up', 8, 23),
#  ('Numerosity Warm-Up', 9, 24),
#  ('Numerosity Warm-Up', 10, 29),
#  ('Numerosity Warm-Up', 11, 26),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 1, 476),
#  ('One Cup Warm-up', 2, 388),
#  ('One Cup Warm-up', 3, 388),
#  ('One Cup Warm-up', 4, 313),
#  ('One Cup Warm-up', 5, 757),
#  ('One Cup Warm-up', 6, 745),
#  ('One Cup Warm-up', 7, 536),
#  ('One Cup Warm-up', 8, 416),
#  ('One Cup Warm-up', 9, 602),
#  ('One Cup Warm-up', 10, 1272),
#  ('One Cup Warm-up', 11, 491),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 1, 8),
#  ('Self Control Game', 2, 8),
#  ('Self Control Game', 3, 11),
#  ('Self Control Game', 4, 9),
#  ('Self Control Game', 5, 9),
#  ('Self Control Game', 6, 11),
#  ('Self Control Game', 7, 14),
#  ('Self Control Game', 8, 13),
#  ('Self Control Game', 9, 19),
#  ('Self Control Game', 10, 9),
#  ('Self Control Game', 11, 15),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 1, 2),
#  ('Shaker Game', 2, 9),
#  ('Shaker Game', 3, 8),
#  ('Shaker Game', 4, 4),
#  ('Shaker Game', 5, 10),
#  ('Shaker Game', 6, 7),
#  ('Shaker Game', 7, 5),
#  ('Shaker Game', 8, 6),
#  ('Shaker Game', 9, 12),
#  ('Shaker Game', 10, 10),
#  ('Shaker Game', 11, 3),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 1, 1),
#  ('Shared Perspective', 2, 3),
#  ('Shared Perspective', 3, 3),
#  ('Shared Perspective', 4, 8),
#  ('Shared Perspective', 5, 11),
#  ('Shared Perspective', 6, 11),
#  ('Shared Perspective', 7, 7),
#  ('Shared Perspective', 8, 10),
#  ('Shared Perspective', 9, 12),
#  ('Shared Perspective', 10, 4),
#  ('Shared Perspective', 11, 6),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 1, 17),
#  ('Slide', 2, 12),
#  ('Slide', 3, 16),
#  ('Slide', 4, 11),
#  ('Slide', 5, 17),
#  ('Slide', 6, 10),
#  ('Slide', 7, 13),
#  ('Slide', 8, 6),
#  ('Slide', 9, 18),
#  ('Slide', 10, 7),
#  ('Slide', 11, 13),
#  ('Slide', 12, 7),
#  ('Smell Game', 1, 13),
#  ('Smell Game', 2, 18),
#  ('Smell Game', 3, 16),
#  ('Smell Game', 4, 6),
#  ('Smell Game', 5, 19),
#  ('Smell Game', 6, 9),
#  ('Smell Game', 7, 21),
#  ('Smell Game', 8, 10),
#  ('Smell Game', 9, 16),
#  ('Smell Game', 10, 15),
#  ('Smell Game', 11, 12),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 1, 12),
#  ('Stair Game', 2, 8),
#  ('Stair Game', 3, 7),
#  ('Stair Game', 4, 4),
#  ('Stair Game', 5, 10),
#  ('Stair Game', 6, 7),
#  ('Stair Game', 7, 14),
#  ('Stair Game', 8, 15),
#  ('Stair Game', 9, 17),
#  ('Stair Game', 10, 7),
#  ('Stair Game', 11, 3),
#  ('Stair Game', 12, 8),
#  ('Switch', 1, 15),
#  ('Switch', 2, 12),
#  ('Switch', 3, 14),
#  ('Switch', 4, 11),
#  ('Switch', 5, 15),
#  ('Switch', 6, 11),
#  ('Switch', 7, 11),
#  ('Switch', 8, 10),
#  ('Switch', 9, 13),
#  ('Switch', 10, 9),
#  ('Switch', 11, 10),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 1, 626),
#  ('Treat Warm-up', 2, 495),
#  ('Treat Warm-up', 3, 515),
#  ('Treat Warm-up', 4, 393),
#  ('Treat Warm-up', 5, 1182),
#  ('Treat Warm-up', 6, 1444),
#  ('Treat Warm-up', 7, 951),
#  ('Treat Warm-up', 8, 791),
#  ('Treat Warm-up', 9, 1303),
#  ('Treat Warm-up', 10, 2626),
#  ('Treat Warm-up', 11, 744),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 1, 462),
#  ('Turn Your Back', 2, 372),
#  ('Turn Your Back', 3, 418),
#  ('Turn Your Back', 4, 298),
#  ('Turn Your Back', 5, 769),
#  ('Turn Your Back', 6, 778),
#  ('Turn Your Back', 7, 535),
#  ('Turn Your Back', 8, 418),
#  ('Turn Your Back', 9, 599),
#  ('Turn Your Back', 10, 1711),
#  ('Turn Your Back', 11, 601),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 1, 490),
#  ('Two Cup Warm-up', 2, 386),
#  ('Two Cup Warm-up', 3, 389),
#  ('Two Cup Warm-up', 4, 308),
#  ('Two Cup Warm-up', 5, 747),
#  ('Two Cup Warm-up', 6, 732),
#  ('Two Cup Warm-up', 7, 537),
#  ('Two Cup Warm-up', 8, 419),
#  ('Two Cup Warm-up', 9, 578),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Two Cup Warm-up', 11, 482),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 1, 70),
#  ('Warm-up', 2, 77),
#  ('Warm-Up', 3, 79),
#  ('Warm-Up', 4, 54),
#  ('Warm-Up', 5, 71),
#  ('Warm-Up', 6, 64),
#  ('Warm-Up', 7, 101),
#  ('Warm-Up', 8, 64),
#  ('Warm-Up', 9, 103),
#  ('Warm-up', 10, 69),
#  ('Warm-Up', 11, 65),
#  ('Warm-up', 12, 56),
#  ('Watching', 1, 594),
#  ('Watching', 2, 443),
#  ('Watching', 3, 472),
#  ('Watching', 4, 322),
#  ('Watching', 5, 980),
#  ('Watching', 6, 1035),
#  ('Watching', 7, 679),
#  ('Watching', 8, 511),
#  ('Watching', 9, 809),
#  ('Watching', 10, 1797),
#  ('Watching', 11, 611),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 1, 445),
#  ('Watching - Part 2', 2, 372),
#  ('Watching - Part 2', 3, 406),
#  ('Watching - Part 2', 4, 282),
#  ('Watching - Part 2', 5, 734),
#  ('Watching - Part 2', 6, 747),
#  ('Watching - Part 2', 7, 504),
#  ('Watching - Part 2', 8, 405),
#  ('Watching - Part 2', 9, 568),
#  ('Watching - Part 2', 10, 1578),
#  ('Watching - Part 2', 11, 565),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 1, 828),
#  ('Yawn Game', 2, 709),
#  ('Yawn Game', 3, 681),
#  ('Yawn Game', 4, 525),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Game', 11, 989),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 1, 834),
#  ('Yawn Warm-up', 2, 712),
#  ('Yawn Warm-up', 3, 698),
#  ('Yawn Warm-up', 4, 541),
#  ('Yawn Warm-up', 5, 2143),
#  ('Yawn Warm-up', 6, 3071),
#  ('Yawn Warm-up', 7, 1909),
#  ('Yawn Warm-up', 8, 1694),
#  ('Yawn Warm-up', 9, 2771),
#  ('Yawn Warm-up', 10, 4387),
#  ('Yawn Warm-up', 11, 1060),
#  ('Yawn Warm-up', 12, 1043)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# Out:
# 12 rows affected.
# [('Delayed Cup Game', 1, 11068),
#  ('Yawn Warm-up', 2, 9122),
#  ('Yawn Warm-up', 3, 9572),
#  ('Physical Reasoning Game', 4, 7130),
#  ('Delayed Cup Game', 5, 21013),
#  ('Foot Pointing', 6, 23381),
#  ('Eye Contact Game', 7, 15977),
#  ('Memory versus Smell', 8, 13382),
#  ('Yawn Warm-up', 9, 19853),
#  ('Yawn Warm-up', 10, 39237),
#  ('Inferential Reasoning Warm-up', 11, 12652),
#  ('Inferential Reasoning Warm-up', 12, 10859)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34),
#  ('3 vs 1 Game', 4, 16),
#  ('3 vs 1 Game', 5, 34),
#  ('3 vs 1 Game', 6, 42),
#  ('3 vs 1 Game', 7, 37),
#  ('3 vs 1 Game', 8, 23),
#  ('3 vs 1 Game', 9, 24),
#  ('3 vs 1 Game', 10, 28),
#  ('3 vs 1 Game', 11, 22),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 1, 59),
#  ('5 vs 1 Game', 2, 54),
#  ('5 vs 1 Game', 3, 57),
#  ('5 vs 1 Game', 4, 29),
#  ('5 vs 1 Game', 5, 50),
#  ('5 vs 1 Game', 6, 61),
#  ('5 vs 1 Game', 7, 69),
#  ('5 vs 1 Game', 8, 38),
#  ('5 vs 1 Game', 9, 50),
#  ('5 vs 1 Game', 10, 54),
#  ('5 vs 1 Game', 11, 40),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 1, 622),
#  ('Arm Pointing', 2, 498),
#  ('Arm Pointing', 3, 507),
#  ('Arm Pointing', 4, 381),
#  ('Arm Pointing', 5, 1149),
#  ('Arm Pointing', 6, 1424),
#  ('Arm Pointing', 7, 913),
#  ('Arm Pointing', 8, 779),
#  ('Arm Pointing', 9, 1243),
#  ('Arm Pointing', 10, 2535),
#  ('Arm Pointing', 11, 735),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 1, 452),
#  ('Cover Your Eyes', 2, 373),
#  ('Cover Your Eyes', 3, 416),
#  ('Cover Your Eyes', 4, 291),
#  ('Cover Your Eyes', 5, 753),
#  ('Cover Your Eyes', 6, 767),
#  ('Cover Your Eyes', 7, 521),
#  ('Cover Your Eyes', 8, 408),
#  ('Cover Your Eyes', 9, 574),
#  ('Cover Your Eyes', 10, 1653),
#  ('Cover Your Eyes', 11, 595),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 1, 356),
#  ('Delayed Cup Game', 2, 319),
#  ('Delayed Cup Game', 3, 350),
#  ('Delayed Cup Game', 4, 256),
#  ('Delayed Cup Game', 5, 539),
#  ('Delayed Cup Game', 6, 525),
#  ('Delayed Cup Game', 7, 407),
#  ('Delayed Cup Game', 8, 355),
#  ('Delayed Cup Game', 9, 424),
#  ('Delayed Cup Game', 10, 1019),
#  ('Delayed Cup Game', 11, 422),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 1, 2),
#  ('Different Perspective', 2, 3),
#  ('Different Perspective', 3, 4),
#  ('Different Perspective', 4, 8),
#  ('Different Perspective', 5, 12),
#  ('Different Perspective', 6, 11),
#  ('Different Perspective', 7, 8),
#  ('Different Perspective', 8, 10),
#  ('Different Perspective', 9, 12),
#  ('Different Perspective', 10, 4),
#  ('Different Perspective', 11, 6),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 1, 6),
#  ('Expression Game', 2, 9),
#  ('Expression Game', 3, 12),
#  ('Expression Game', 4, 10),
#  ('Expression Game', 5, 9),
#  ('Expression Game', 6, 11),
#  ('Expression Game', 7, 12),
#  ('Expression Game', 8, 11),
#  ('Expression Game', 9, 17),
#  ('Expression Game', 10, 3),
#  ('Expression Game', 11, 11),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 1, 506),
#  ('Foot Pointing', 2, 433),
#  ('Foot Pointing', 3, 477),
#  ('Foot Pointing', 4, 339),
#  ('Foot Pointing', 5, 926),
#  ('Foot Pointing', 6, 1125),
#  ('Foot Pointing', 7, 759),
#  ('Foot Pointing', 8, 653),
#  ('Foot Pointing', 9, 992),
#  ('Foot Pointing', 10, 2290),
#  ('Foot Pointing', 11, 685),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 1, 465),
#  ('Memory versus Smell', 2, 374),
#  ('Memory versus Smell', 3, 382),
#  ('Memory versus Smell', 4, 280),
#  ('Memory versus Smell', 5, 667),
#  ('Memory versus Smell', 6, 666),
#  ('Memory versus Smell', 7, 491),
#  ('Memory versus Smell', 8, 402),
#  ('Memory versus Smell', 9, 529),
#  ('Memory versus Smell', 10, 1111),
#  ('Memory versus Smell', 11, 444),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 1, 57),
#  ('Navigation Game', 2, 41),
#  ('Navigation Game', 3, 47),
#  ('Navigation Game', 4, 41),
#  ('Navigation Game', 5, 336),
#  ('Navigation Game', 6, 81),
#  ('Navigation Game', 7, 70),
#  ('Navigation Game', 8, 41),
#  ('Navigation Game', 9, 52),
#  ('Navigation Game', 10, 69),
#  ('Navigation Game', 11, 47),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 1, 62),
#  ('Navigation Warm-up', 2, 43),
#  ('Navigation Warm-up', 3, 50),
#  ('Navigation Warm-up', 4, 42),
#  ('Navigation Warm-up', 5, 625),
#  ('Navigation Warm-up', 6, 114),
#  ('Navigation Warm-up', 7, 88),
#  ('Navigation Warm-up', 8, 40),
#  ('Navigation Warm-up', 9, 58),
#  ('Navigation Warm-up', 10, 76),
#  ('Navigation Warm-up', 11, 52),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 1, 36),
#  ('Numerosity Warm-Up', 2, 28),
#  ('Numerosity Warm-Up', 3, 35),
#  ('Numerosity Warm-Up', 4, 17),
#  ('Numerosity Warm-Up', 5, 37),
#  ('Numerosity Warm-Up', 6, 44),
#  ('Numerosity Warm-Up', 7, 37),
#  ('Numerosity Warm-Up', 8, 23),
#  ('Numerosity Warm-Up', 9, 24),
#  ('Numerosity Warm-Up', 10, 29),
#  ('Numerosity Warm-Up', 11, 26),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 1, 476),
#  ('One Cup Warm-up', 2, 388),
#  ('One Cup Warm-up', 3, 388),
#  ('One Cup Warm-up', 4, 313),
#  ('One Cup Warm-up', 5, 757),
#  ('One Cup Warm-up', 6, 745),
#  ('One Cup Warm-up', 7, 536),
#  ('One Cup Warm-up', 8, 416),
#  ('One Cup Warm-up', 9, 602),
#  ('One Cup Warm-up', 10, 1272),
#  ('One Cup Warm-up', 11, 491),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 1, 8),
#  ('Self Control Game', 2, 8),
#  ('Self Control Game', 3, 11),
#  ('Self Control Game', 4, 9),
#  ('Self Control Game', 5, 9),
#  ('Self Control Game', 6, 11),
#  ('Self Control Game', 7, 14),
#  ('Self Control Game', 8, 13),
#  ('Self Control Game', 9, 19),
#  ('Self Control Game', 10, 9),
#  ('Self Control Game', 11, 15),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 1, 2),
#  ('Shaker Game', 2, 9),
#  ('Shaker Game', 3, 8),
#  ('Shaker Game', 4, 4),
#  ('Shaker Game', 5, 10),
#  ('Shaker Game', 6, 7),
#  ('Shaker Game', 7, 5),
#  ('Shaker Game', 8, 6),
#  ('Shaker Game', 9, 12),
#  ('Shaker Game', 10, 10),
#  ('Shaker Game', 11, 3),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 1, 1),
#  ('Shared Perspective', 2, 3),
#  ('Shared Perspective', 3, 3),
#  ('Shared Perspective', 4, 8),
#  ('Shared Perspective', 5, 11),
#  ('Shared Perspective', 6, 11),
#  ('Shared Perspective', 7, 7),
#  ('Shared Perspective', 8, 10),
#  ('Shared Perspective', 9, 12),
#  ('Shared Perspective', 10, 4),
#  ('Shared Perspective', 11, 6),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 1, 17),
#  ('Slide', 2, 12),
#  ('Slide', 3, 16),
#  ('Slide', 4, 11),
#  ('Slide', 5, 17),
#  ('Slide', 6, 10),
#  ('Slide', 7, 13),
#  ('Slide', 8, 6),
#  ('Slide', 9, 18),
#  ('Slide', 10, 7),
#  ('Slide', 11, 13),
#  ('Slide', 12, 7),
#  ('Smell Game', 1, 13),
#  ('Smell Game', 2, 18),
#  ('Smell Game', 3, 16),
#  ('Smell Game', 4, 6),
#  ('Smell Game', 5, 19),
#  ('Smell Game', 6, 9),
#  ('Smell Game', 7, 21),
#  ('Smell Game', 8, 10),
#  ('Smell Game', 9, 16),
#  ('Smell Game', 10, 15),
#  ('Smell Game', 11, 12),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 1, 12),
#  ('Stair Game', 2, 8),
#  ('Stair Game', 3, 7),
#  ('Stair Game', 4, 4),
#  ('Stair Game', 5, 10),
#  ('Stair Game', 6, 7),
#  ('Stair Game', 7, 14),
#  ('Stair Game', 8, 15),
#  ('Stair Game', 9, 17),
#  ('Stair Game', 10, 7),
#  ('Stair Game', 11, 3),
#  ('Stair Game', 12, 8),
#  ('Switch', 1, 15),
#  ('Switch', 2, 12),
#  ('Switch', 3, 14),
#  ('Switch', 4, 11),
#  ('Switch', 5, 15),
#  ('Switch', 6, 11),
#  ('Switch', 7, 11),
#  ('Switch', 8, 10),
#  ('Switch', 9, 13),
#  ('Switch', 10, 9),
#  ('Switch', 11, 10),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 1, 626),
#  ('Treat Warm-up', 2, 495),
#  ('Treat Warm-up', 3, 515),
#  ('Treat Warm-up', 4, 393),
#  ('Treat Warm-up', 5, 1182),
#  ('Treat Warm-up', 6, 1444),
#  ('Treat Warm-up', 7, 951),
#  ('Treat Warm-up', 8, 791),
#  ('Treat Warm-up', 9, 1303),
#  ('Treat Warm-up', 10, 2626),
#  ('Treat Warm-up', 11, 744),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 1, 462),
#  ('Turn Your Back', 2, 372),
#  ('Turn Your Back', 3, 418),
#  ('Turn Your Back', 4, 298),
#  ('Turn Your Back', 5, 769),
#  ('Turn Your Back', 6, 778),
#  ('Turn Your Back', 7, 535),
#  ('Turn Your Back', 8, 418),
#  ('Turn Your Back', 9, 599),
#  ('Turn Your Back', 10, 1711),
#  ('Turn Your Back', 11, 601),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 1, 490),
#  ('Two Cup Warm-up', 2, 386),
#  ('Two Cup Warm-up', 3, 389),
#  ('Two Cup Warm-up', 4, 308),
#  ('Two Cup Warm-up', 5, 747),
#  ('Two Cup Warm-up', 6, 732),
#  ('Two Cup Warm-up', 7, 537),
#  ('Two Cup Warm-up', 8, 419),
#  ('Two Cup Warm-up', 9, 578),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Two Cup Warm-up', 11, 482),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 1, 70),
#  ('Warm-up', 2, 77),
#  ('Warm-Up', 3, 79),
#  ('Warm-Up', 4, 54),
#  ('Warm-Up', 5, 71),
#  ('Warm-Up', 6, 64),
#  ('Warm-Up', 7, 101),
#  ('Warm-Up', 8, 64),
#  ('Warm-Up', 9, 103),
#  ('Warm-up', 10, 69),
#  ('Warm-Up', 11, 65),
#  ('Warm-up', 12, 56),
#  ('Watching', 1, 594),
#  ('Watching', 2, 443),
#  ('Watching', 3, 472),
#  ('Watching', 4, 322),
#  ('Watching', 5, 980),
#  ('Watching', 6, 1035),
#  ('Watching', 7, 679),
#  ('Watching', 8, 511),
#  ('Watching', 9, 809),
#  ('Watching', 10, 1797),
#  ('Watching', 11, 611),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 1, 445),
#  ('Watching - Part 2', 2, 372),
#  ('Watching - Part 2', 3, 406),
#  ('Watching - Part 2', 4, 282),
#  ('Watching - Part 2', 5, 734),
#  ('Watching - Part 2', 6, 747),
#  ('Watching - Part 2', 7, 504),
#  ('Watching - Part 2', 8, 405),
#  ('Watching - Part 2', 9, 568),
#  ('Watching - Part 2', 10, 1578),
#  ('Watching - Part 2', 11, 565),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 1, 828),
#  ('Yawn Game', 2, 709),
#  ('Yawn Game', 3, 681),
#  ('Yawn Game', 4, 525),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Game', 11, 989),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 1, 834),
#  ('Yawn Warm-up', 2, 712),
#  ('Yawn Warm-up', 3, 698),
#  ('Yawn Warm-up', 4, 541),
#  ('Yawn Warm-up', 5, 2143),
#  ('Yawn Warm-up', 6, 3071),
#  ('Yawn Warm-up', 7, 1909),
#  ('Yawn Warm-up', 8, 1694),
#  ('Yawn Warm-up', 9, 2771),
#  ('Yawn Warm-up', 10, 4387),
#  ('Yawn Warm-up', 11, 1060),
#  ('Yawn Warm-up', 12, 1043)]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT gender ,breed_group, count(distinct dog_guid) AS number
# from dogs
# group by breed_group, gender
# order by number desc
# Out:
# 18 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075),
#  ('female', 'Non-Sporting', 919),
#  ('male', 'Terrier', 919),
#  ('female', 'Working', 895),
#  ('female', 'Terrier', 794),
#  ('male', 'Hound', 725),
#  ('female', 'Hound', 614),
#  ('male', '', 147),
#  ('female', '', 127)]

# %%
# %%sql
# select distinct trim(leading '-' from breed) as dis_breed, count(gender) as number
# from dogs
# group by dis_breed
# order by number desc
# Out:
# 2006 rows affected.
# [('Mixed', 8002),
#  ('Labrador Retriever', 2206),
#  ('Golden Retriever', 1296),
#  ('German Shepherd Dog', 1040),
#  ("I Don't Know", 979),
#  ('Poodle', 682),
#  ('Border Collie', 644),
#  ('Australian Shepherd', 624),
#  ('Shih Tzu', 522),
#  ('Other', 518),
#  ('Golden Doodle', 446),
#  ('Dachshund', 444),
#  ('Boxer', 426),
#  ('Chihuahua', 389),
#  ('Labradoodle', 345),
#  ('Miniature Schnauzer', 340),
#  ('American Pit Bull Terrier', 330),
#  ('Yorkshire Terrier', 323),
#  ('Beagle', 312),
#  ('Labrador Retriever-Golden Retriever Mix', 254),
#  ('Shetland Sheepdog', 245),
#  ('Pug', 231),
#  ('Boston Terrier', 227),
#  ('Doberman Pinscher', 224),
#  ('Cocker Spaniel', 221),
#  ('Bulldog', 206),
#  ('Siberian Husky', 201),
#  ('English Springer Spaniel', 201),
#  ('Cavalier King Charles Spaniel', 197),
#  ('French Bulldog', 195),
#  ('Maltese', 194),
#  ('Rottweiler', 186),
#  ('Havanese', 181),
#  ('West Highland White Terrier', 174),
#  ('Cockapoo', 174),
#  ('Pembroke Welsh Corgi', 169),
#  ('Australian Cattle Dog', 169),
#  ('Bichon Frise', 166),
#  ('Pomeranian', 162),
#  ('Golden Retriever-Labrador Retriever Mix', 162),
#  ('Parson Russell Terrier', 158),
#  ('Jack Russell Terrier', 142),
#  ('Great Dane', 141),
#  ('Weimaraner', 135),
#  ('Vizsla', 130),
#  ('Soft Coated Wheaten Terrier', 122),
#  ('Rhodesian Ridgeback', 120),
#  ('Portuguese Water Dog', 113),
#  ('Russell Terrier', 110),
#  ('American Staffordshire Terrier', 110),
#  ('Rat Terrier', 105),
#  ('Miniature Pinscher', 105),
#  ('Shiba Inu', 103),
#  ('Basset Hound', 103),
#  ('German Shorthaired Pointer', 101),
#  ('Standard Poodle', 99),
#  ('Bernese Mountain Dog', 98),
#  ('Greyhound', 98),
#  ('Collie', 98),
#  ('Papillon', 97),
#  ('Belgian Malinois', 96),
#  ('Brittany', 93),
#  ('Maltese-Poodle Mix', 88),
#  ('Cairn Terrier', 82),
#  ('Puggle', 82),
#  ('Border Terrier', 79),
#  ('English Cocker Spaniel', 79),
#  ('Staffordshire Bull Terrier', 76),
#  ('Whippet', 68),
#  ('Flat-Coated Retriever', 66),
#  ('Coton de Tulear', 65),
#  ('Australian Labradoodle', 65),
#  ('Dalmatian', 64),
#  ('American Eskimo Dog', 63),
#  ('Border Collie-Labrador Retriever Mix', 61),
#  ('Newfoundland', 60),
#  ('Nova Scotia Duck Tolling Retriever', 58),
#  ('Airedale Terrier', 55),
#  ('Akita', 52),
#  ('Standard Schnauzer', 52),
#  ('Labrador Retriever-Border Collie Mix', 51),
#  ('Alaskan Malamute', 50),
#  ('Golden Retriever-Poodle Mix', 50),
#  ('Samoyed', 49),
#  ('Labrador Retriever-German Shepherd Dog Mix', 49),
#  ('Shih Tzu-Poodle Mix', 48),
#  ('Maltese-Yorkshire Terrier Mix', 47),
#  ('Cocker Spaniel-Poodle Mix', 47),
#  ('Bouvier des Flandres', 46),
#  ('Yorkshire Terrier-Poodle Mix', 46),
#  ('Border Collie-Australian Shepherd Mix', 46),
#  ('Miniature Schnauzer-Poodle Mix', 46),
#  ('German Shepherd Dog-Labrador Retriever Mix', 46),
#  ('Great Pyrenees', 46),
#  ('Chihuahua-Dachshund Mix', 45),
#  ('Bull Terrier', 45),
#  ('Mastiff', 45),
#  ('Labrador Retriever-American Pit Bull Terrier Mix', 45),
#  ('Australian Shepherd-Border Collie Mix', 44),
#  ('Scottish Terrier', 44),
#  ('Italian Greyhound', 40),
#  ('Lhasa Apso', 40),
#  ('St. Bernard', 40),
#  ('Catahoula Leopard Dog', 40),
#  ('Cardigan Welsh Corgi', 39),
#  ('Bichon Frise-Poodle Mix', 39),
#  ('Tibetan Terrier', 39),
#  ('German Shepherd Dog-Siberian Husky Mix', 38),
#  ('Chinese Crested', 38),
#  ('Miniature American Shepherd', 37),
#  ('Belgian Tervuren', 35),
#  ('English Setter', 35),
#  ('Poodle-Miniature Schnauzer Mix', 34),
#  ('Border Collie-Australian Cattle Dog Mix', 34),
#  ('Cane Corso', 34),
#  ('Shorkie', 33),
#  ('Miniature Australian Shepherd', 32),
#  ('Chesapeake Bay Retriever', 31),
#  ('Old English Sheepdog', 31),
#  ('Cavalier King Charles Spaniel-Poodle Mix', 31),
#  ('Bearded Collie', 31),
#  ('Labrador Retriever-Poodle Mix', 31),
#  ('American Pit Bull Terrier-Labrador Retriever Mix', 31),
#  ('Siberian Husky-German Shepherd Dog Mix', 30),
#  ('Silky Terrier', 30),
#  ('Boxer-Labrador Retriever Mix', 30),
#  ('Poodle-Maltese Mix', 29),
#  ('Chinese Shar-Pei', 29),
#  ('Bullmastiff', 29),
#  ('Brussels Griffon', 28),
#  ('Yorkshire Terrier-Maltese Mix', 28),
#  ('Pekingese', 28),
#  ('Bichon Frise-Shih Tzu Mix', 27),
#  ('Basenji', 27),
#  ('American Pit Bull Terrier-Boxer Mix', 27),
#  ('Irish Setter', 26),
#  ('Maltese-Shih Tzu Mix', 26),
#  ('Dutch Shepherd', 26),
#  ('Leonberger', 25),
#  ('Poodle-Shih Tzu Mix', 25),
#  ('Chow Chow', 25),
#  ('Wire Fox Terrier', 24),
#  ('Australian Shepherd-Poodle Mix', 24),
#  ('German Wirehaired Pointer', 24),
#  ('Australian Terrier', 23),
#  ('Australian Cattle Dog-Border Collie Mix', 23),
#  ('Chihuahua-Miniature Pinscher Mix', 23),
#  ('Labrador Retriever-Rottweiler Mix', 23),
#  ('Labrador Retriever-Weimaraner Mix', 23),
#  ('Keeshond', 22),
#  ('Treeing Walker Coonhound', 22),
#  ('Welsh Terrier', 22),
#  ('Australian Kelpie', 22),
#  ('Lagotto Romagnolo', 21),
#  ('Greater Swiss Mountain Dog', 21),
#  ('Chihuahua-Yorkshire Terrier Mix', 21),
#  ('Welsh Springer Spaniel', 20),
#  ('Beagle-Labrador Retriever Mix', 20),
#  ('Poodle-Yorkshire Terrier Mix', 20),
#  ('Schipperke', 20),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix', 19),
#  ('BullBoxer', 19),
#  ('Dachshund-Chihuahua Mix', 19),
#  ('Shih Tzu-Bichon Frise Mix', 19),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', 18),
#  ('Labrador Retriever- Mix', 18),
#  ('American Staffordshire Terrier-American Pit Bull Terrier Mix', 18),
#  ('Pomapoo', 18),
#  ('Border Collie-German Shepherd Dog Mix', 18),
#  ('Pointer', 18),
#  ('Australian Shepherd-Labrador Retriever Mix', 18),
#  ('Chihuahua-Rat Terrier Mix', 17),
#  ('Giant Schnauzer', 17),
#  ('Poodle-Bichon Frise Mix', 17),
#  ('Norwich Terrier', 17),
#  ('Briard', 17),
#  ('Irish Terrier', 17),
#  ('Chihuahua-Pomeranian Mix', 17),
#  ('Shih Tzu-Maltese Mix', 16),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix', 16),
#  ('Afghan Hound', 16),
#  ('Toy Fox Terrier', 16),
#  ('Australian Cattle Dog-Australian Shepherd Mix', 16),
#  ('Boxer-American Pit Bull Terrier Mix', 16),
#  ('Beaglier', 16),
#  ('Lhasa Apso-Poodle Mix', 15),
#  ('German Shepherd Dog-Chow Chow Mix', 15),
#  ('Irish Wolfhound', 15),
#  ('Anatolian Shepherd Dog', 15),
#  ('Belgian Sheepdog', 15),
#  ('Chihuahua-Pug Mix', 15),
#  ('German Spitz', 15),
#  ('German Shepherd Dog-Rottweiler Mix', 15),
#  ('Hovawart', 15),
#  ('Australian Cattle Dog-Labrador Retriever Mix', 15),
#  ('Labrador Retriever-Australian Shepherd Mix', 15),
#  ('Chihuahua-Jack Russell Terrier Mix', 15),
#  ('Bugg', 14),
#  ('Tibetan Spaniel', 14),
#  ('Redbone Coonhound', 14),
#  ('German Shepherd Dog-Golden Retriever Mix', 14),
#  ('Wirehaired Pointing Griffon', 14),
#  ('Norwegian Elkhound', 14),
#  ('Border Collie-Golden Retriever Mix', 14),
#  ('Chihuahua-Russell Terrier Mix', 14),
#  ('Gordon Setter', 14),
#  ('Poodle-Cocker Spaniel Mix', 13),
#  ('Affenpinscher', 13),
#  ('Bluetick Coonhound', 13),
#  ('Spinone Italiano', 13),
#  ('German Shepherd Dog-Australian Shepherd Mix', 13),
#  ('Spanish Water Dog', 13),
#  ('Pomeranian-Chihuahua Mix', 13),
#  ('Border Collie-Siberian Husky Mix', 13),
#  ('Australian Cattle Dog-German Shepherd Dog Mix', 13),
#  ('Beauceron', 13),
#  ('Labrador Retriever-Siberian Husky Mix', 13),
#  ('Poodle-Golden Retriever Mix', 13),
#  ('Bedlington Terrier', 12),
#  ('Golden Retriever-German Shepherd Dog Mix', 12),
#  ('Icelandic Sheepdog', 12),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 12),
#  ('Australian Shepherd-Australian Cattle Dog Mix', 12),
#  ('Dogo Argentino', 12),
#  ('German Shepherd Dog- Mix', 12),
#  ('Rottweiler-Labrador Retriever Mix', 12),
#  ('Labrador Retriever-Great Dane Mix', 12),
#  ('Siberian Husky-Labrador Retriever Mix', 12),
#  ('Labrador Retriever-Boxer Mix', 12),
#  ('German Shepherd Dog-Border Collie Mix', 11),
#  ('Norfolk Terrier', 11),
#  ('Field Spaniel', 11),
#  ('Rottweiler-German Shepherd Dog Mix', 11),
#  ('Kerry Blue Terrier', 11),
#  ('Eurasier', 11),
#  ('Rat Terrier-Chihuahua Mix', 11),
#  ('Finnish Lapphund', 11),
#  ('Labrador Retriever Mix', 11),
#  ('Catahoula Leopard Dog-Labrador Retriever Mix', 11),
#  ('Labrador Retriever-Beagle Mix', 11),
#  ('Irish Water Spaniel', 11),
#  ('Dogue de Bordeaux', 11),
#  ('Jack-A-Poo', 11),
#  ('Labrador Retriever-Chow Chow Mix', 11),
#  ('Yorkshire Terrier-Miniature Schnauzer Mix', 11),
#  ('Boykin Spaniel', 10),
#  ('Labrador Retriever-Australian Cattle Dog Mix', 10),
#  ('American Staffordshire Terrier-Labrador Retriever Mix', 10),
#  ('Poodle-Labrador Retriever Mix', 10),
#  ('Boston Terrier-French Bulldog Mix', 10),
#  ('Black Russian Terrier', 10),
#  ('Puli', 10),
#  ('Smooth Fox Terrier', 10),
#  ('Borzoi', 10),
#  ('Labrador Retriever-German Shorthaired Pointer Mix', 10),
#  ('Lhasa Apso-Shih Tzu Mix', 10),
#  ('Alaskan Malamute-Siberian Husky Mix', 10),
#  ('Beagle-Dachshund Mix', 10),
#  ('Xoloitzcuintli', 10),
#  ('American Staffordshire Terrier-Boxer Mix', 10),
#  ('German Shorthaired Pointer-Labrador Retriever Mix', 9),
#  ('German Shepherd Dog-Belgian Malinois Mix', 9),
#  ('Shih Tzu-Yorkshire Terrier Mix', 9),
#  ('Border Collie-English Springer Spaniel Mix', 9),
#  ('Beagle-Russell Terrier Mix', 9),
#  ('Canaan Dog', 9),
#  ('Yorkshire Terrier-Chihuahua Mix', 9),
#  ('American Pit Bull Terrier-Bulldog Mix', 9),
#  ('Manchester Terrier', 9),
#  ('Beagle-Border Collie Mix', 9),
#  ('Boerboel', 9),
#  ('Jack Russell Terrier-Chihuahua Mix', 9),
#  ('Neapolitan Mastiff', 8),
#  ('Kooikerhondje', 8),
#  ('Pug-Chihuahua Mix', 8),
#  ('American Water Spaniel', 8),
#  ('Australian Shepherd-Golden Retriever Mix', 8),
#  ('Pyrenean Shepherd', 8),
#  ('German Shepherd Dog Mix', 8),
#  ('Chinook', 8),
#  ('Berger Picard', 8),
#  ('Pekingese-Poodle Mix', 8),
#  ('Japanese Chin', 8),
#  ('Yorkshire Terrier-Shih Tzu Mix', 8),
#  ('Entlebucher Mountain Dog', 8),
#  ('German Shepherd Dog-American Pit Bull Terrier Mix', 8),
#  ('Saluki', 8),
#  ('German Shepherd Dog-Doberman Pinscher Mix', 8),
#  ('Clumber Spaniel', 8),
#  ('Beagle-Pug Mix', 8),
#  ('Chihuahua-Italian Greyhound Mix', 8),
#  ('Labrador Retriever-Pointer Mix', 8),
#  ('Labrador Retriever-Staffordshire Bull Terrier Mix', 8),
#  ('Bloodhound', 8),
#  ('Labrador Retriever-American Staffordshire Terrier Mix', 8),
#  ('Stabyhoun', 8),
#  ('Alaskan Malamute-German Shepherd Dog Mix', 8),
#  ('Australian Shepherd-German Shepherd Dog Mix', 7),
#  ('Chihuahua- Mix', 7),
#  ('Labrador Retriever-Chinese Shar-Pei Mix', 7),
#  ('Dachshund-Miniature Pinscher Mix', 7),
#  ('Yorkshire Terrier-Bichon Frise Mix', 7),
#  ('Boxer-American Staffordshire Terrier Mix', 7),
#  ('Shih Tzu-Pekingese Mix', 7),
#  ('Dachshund-Beagle Mix', 7),
#  ('Chow Chow-Labrador Retriever Mix', 7),
#  ('Australian Shepherd- Mix', 7),
#  ('Labrador Retriever-Collie Mix', 7),
#  ('Border Collie- Mix', 7),
#  ('Pug-Beagle Mix', 7),
#  ('Black and Tan Coonhound', 7),
#  ('Shih Tzu-Lhasa Apso Mix', 7),
#  ('German Shepherd Dog-Alaskan Malamute Mix', 7),
#  ('German Pinscher', 7),
#  ('Labrador Retriever-English Springer Spaniel Mix', 7),
#  ('Havanese-Poodle Mix', 7),
#  ('Labrador Retriever-Greyhound Mix', 7),
#  ('Boxer-German Shepherd Dog Mix', 7),
#  ('Pomeranian-Yorkshire Terrier Mix', 7),
#  ('Small Munsterlander Pointer', 7),
#  ('German Shepherd Dog-Greyhound Mix', 7),
#  ('Mudi', 6),
#  ('Irish Red and White Setter', 6),
#  ('Golden Retriever-Collie Mix', 6),
#  ('Border Collie-Greyhound Mix', 6),
#  ('Golden Retriever-Great Pyrenees Mix', 6),
#  ('Lakeland Terrier', 6),
#  ('Greyhound-Labrador Retriever Mix', 6),
#  ('Norwegian Buhund', 6),
#  ('Swedish Vallhund', 6),
#  ('Miniature Pinscher-Chihuahua Mix', 6),
#  ('Shetland Sheepdog-Border Collie Mix', 6),
#  ('American Pit Bull Terrier- Mix', 6),
#  ('Dachshund-Yorkshire Terrier Mix', 6),
#  ('Rat Terrier-Russell Terrier Mix', 6),
#  ('Lowchen', 6),
#  ('Pharaoh Hound', 6),
#  ('American Staffordshire Terrier-Border Collie Mix', 6),
#  ('Catahoula Leopard Dog-Australian Cattle Dog Mix', 6),
#  ('Czechoslovakian Vlcak', 6),
#  ('American Foxhound', 6),
#  ('Golden Retriever-Chow Chow Mix', 6),
#  ('Wirehaired Vizsla', 6),
#  ('Doberman Pinscher-Labrador Retriever Mix', 6),
#  ('Labrador Retriever-Chesapeake Bay Retriever Mix', 6),
#  ('Labrador Retriever-Mastiff Mix', 6),
#  ('Chihuahua-Pembroke Welsh Corgi Mix', 6),
#  ('Pug-Shih Tzu Mix', 6),
#  ('Poodle-Chihuahua Mix', 6),
#  ('Collie-Labrador Retriever Mix', 6),
#  ('Siberian Husky-Border Collie Mix', 6),
#  ('Petit Basset Griffon Vendeen', 6),
#  ('Border Collie-Shetland Sheepdog Mix', 6),
#  ('Border Collie-Flat-Coated Retriever Mix', 6),
#  ('Plott', 6),
#  ('Beagle-Basset Hound Mix', 6),
#  ('Golden Retriever-Border Collie Mix', 6),
#  ('Rottweiler-American Pit Bull Terrier Mix', 6),
#  ('Poodle-Soft Coated Wheaten Terrier Mix', 6),
#  ('Australian Cattle Dog- Mix', 5),
#  ('French Spaniel', 5),
#  ('Great Dane-Labrador Retriever Mix', 5),
#  ('Danish-Swedish Farmdog', 5),
#  ('Chow Chow-Golden Retriever Mix', 5),
#  ('Russell Terrier-Chihuahua Mix', 5),
#  ('Siberian Husky-Australian Shepherd Mix', 5),
#  ('Pekingese-Shih Tzu Mix', 5),
#  ('Polish Lowland Sheepdog', 5),
#  ('Pug-Miniature Pinscher Mix', 5),
#  ('Boxer-Bulldog Mix', 5),
#  ('Poodle- Mix', 5),
#  ('Labrador Retriever-Basset Hound Mix', 5),
#  ('Poodle-Standard Schnauzer Mix', 5),
#  ('Miniature Bull Terrier', 5),
#  ('American Pit Bull Terrier-Pointer Mix', 5),
#  ('American Staffordshire Terrier- Mix', 5),
#  ('German Shepherd Dog-Poodle Mix', 5),
#  ('Glen of Imaal Terrier', 5),
#  ('Labrador Retriever-Dachshund Mix', 5),
#  ('Rhodesian Ridgeback-Labrador Retriever Mix', 5),
#  ('Australian Cattle Dog Mix', 5),
#  ('German Shepherd Dog-Boxer Mix', 5),
#  ('Dachshund-Poodle Mix', 5),
#  ('Collie-German Shepherd Dog Mix', 5),
#  ('American Pit Bull Terrier Mix', 5),
#  ('Dachshund-Labrador Retriever Mix', 5),
#  ('Basset Hound-Beagle Mix', 5),
#  ('Border Collie Mix', 5),
#  ('Bichon Frise-Maltese Mix', 5),
#  ('Chihuahua-Papillon Mix', 5),
#  ('American Staffordshire Terrier-Bulldog Mix', 5),
#  ('Komondor', 5),
#  ('German Shepherd Dog-Australian Cattle Dog Mix', 5),
#  ('Bulldog-Boxer Mix', 5),
#  ('Beagle-Bluetick Coonhound Mix', 5),
#  ('Basset Hound-Labrador Retriever Mix', 5),
#  ('Staffordshire Bull Terrier-Australian Cattle Dog Mix', 5),
#  ('Bichon Frise-Yorkshire Terrier Mix', 5),
#  ('Bolognese', 5),
#  ('Labrador Retriever-Cocker Spaniel Mix', 5),
#  ('German Shepherd Dog-Rhodesian Ridgeback Mix', 5),
#  ('Australian Shepherd-Shetland Sheepdog Mix', 5),
#  ('Beagle-Jack Russell Terrier Mix', 5),
#  ('American Eskimo Dog-Pomeranian Mix', 5),
#  ('Jack Russell Terrier-Rat Terrier Mix', 5),
#  ('Chihuahua-Pekingese Mix', 5),
#  ('Finnish Spitz', 4),
#  ('Boston Terrier-Chihuahua Mix', 4),
#  ('Doberman Pinscher-German Shepherd Dog Mix', 4),
#  ('Yorkshire Terrier- Mix', 4),
#  ('Beagle-Australian Cattle Dog Mix', 4),
#  ('Border Collie-Dalmatian Mix', 4),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix', 4),
#  ('Border Collie-Whippet Mix', 4),
#  ('Border Collie-Pembroke Welsh Corgi Mix', 4),
#  ('Russell Terrier-Beagle Mix', 4),
#  ('American Pit Bull Terrier-Plott Mix', 4),
#  ('Appenzeller Sennenhunde', 4),
#  ('Chow Chow-Australian Shepherd Mix', 4),
#  ('Australian Shepherd-Chow Chow Mix', 4),
#  ('Poodle-Lhasa Apso Mix', 4),
#  ('Cocker Spaniel-Cavalier King Charles Spaniel Mix', 4),
#  ('Staffordshire Bull Terrier- Mix', 4),
#  ('German Longhaired Pointer', 4),
#  ('Labrador Retriever-Black and Tan Coonhound Mix', 4),
#  ('Bernese Mountain Dog-Golden Retriever Mix', 4),
#  ('Curly-Coated Retriever', 4),
#  ('Miniature Pinscher-Rat Terrier Mix', 4),
#  ('Portuguese Podengo', 4),
#  ('American Hairless Terrier', 4),
#  ('Poodle Mix', 4),
#  ('Pug-French Bulldog Mix', 4),
#  ('Russian Toy', 4),
#  ('Perro de Presa Canario', 4),
#  ('Pumi', 4),
#  ('Pomeranian Mix', 4),
#  ('American Pit Bull Terrier-Australian Shepherd Mix', 4),
#  ('Poodle-Pekingese Mix', 4),
#  ('Belgian Malinois-Labrador Retriever Mix', 4),
#  ('Bernese Mountain Dog-Great Pyrenees Mix', 4),
#  ('French Bulldog-Boston Terrier Mix', 4),
#  ('Australian Shepherd-Great Pyrenees Mix', 4),
#  ('Bullmastiff-Staffordshire Bull Terrier Mix', 4),
#  ('Australian Cattle Dog-Beagle Mix', 4),
#  ('American Pit Bull Terrier-Great Dane Mix', 4),
#  ('Chinese Shar-Pei- Mix', 4),
#  ('Dachshund-Rat Terrier Mix', 4),
#  ('Collie-Golden Retriever Mix', 4),
#  ('Bloodhound-Labrador Retriever Mix', 4),
#  ('Border Collie-Collie Mix', 4),
#  ('Tibetan Mastiff', 4),
#  ('Pug-Russell Terrier Mix', 4),
#  ('Australian Cattle Dog-Siberian Husky Mix', 4),
#  ('Beagle-Rat Terrier Mix', 4),
#  ('Yorkshire Terrier-Silky Terrier Mix', 4),
#  ('Cavalier King Charles Spaniel-Cocker Spaniel Mix', 4),
#  ('Australian Cattle Dog-American Pit Bull Terrier Mix', 4),
#  ('Border Collie-American Pit Bull Terrier Mix', 4),
#  ('Border Collie-Newfoundland Mix', 4),
#  ('Yorkshire Terrier-Pomeranian Mix', 4),
#  ('American Pit Bull Terrier-Rhodesian Ridgeback Mix', 4),
#  ('Soft Coated Wheaten Terrier-Poodle Mix', 4),
#  ('Chesapeake Bay Retriever-Labrador Retriever Mix', 4),
#  ('Mastiff-Great Dane Mix', 4),
#  ('Maltese-Bichon Frise Mix', 4),
#  ('Boxer-Rhodesian Ridgeback Mix', 4),
#  ('Miniature Schnauzer-Yorkshire Terrier Mix', 4),
#  ('Bichon Frise-Lhasa Apso Mix', 4),
#  ('Mastiff-Labrador Retriever Mix', 4),
#  ('Australian Shepherd-Siberian Husky Mix', 4),
#  ('Australian Shepherd-Catahoula Leopard Dog Mix', 4),
#  ('Australian Shepherd-Collie Mix', 4),
#  ('Jindo', 4),
#  ('Border Collie-Bearded Collie Mix', 4),
#  ('Poodle-English Springer Spaniel Mix', 4),
#  ('Standard Poodle-Golden Retriever Mix', 4),
#  ('Akita-German Shepherd Dog Mix', 4),
#  ('Jack Russell Terrier-Pug Mix', 4),
#  ('Australian Labradoodle-Poodle Mix', 4),
#  ('Border Collie-Cocker Spaniel Mix', 4),
#  ('Border Collie-Australian Kelpie Mix', 4),
#  ('Border Collie-Bluetick Coonhound Mix', 4),
#  ('Beagle-Cavalier King Charles Spaniel Mix', 3),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix', 3),
#  ('Pointer-Labrador Retriever Mix', 3),
#  ('Bulldog-Beagle Mix', 3),
#  ('Rhodesian Ridgeback-Boxer Mix', 3),
#  ('German Shepherd Dog-Beagle Mix', 3),
#  ('Border Collie-Staffordshire Bull Terrier Mix', 3),
#  ('Poodle-Dachshund Mix', 3),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix', 3),
#  ('Dandie Dinmont Terrier', 3),
#  ('Redbone Coonhound-Labrador Retriever Mix', 3),
#  ('Brittany-German Shorthaired Pointer Mix', 3),
#  ('Ibizan Hound', 3),
#  ('German Shepherd Dog-Chinese Shar-Pei Mix', 3),
#  ('Russell Terrier-Shih Tzu Mix', 3),
#  ('Poodle-Japanese Chin Mix', 3),
#  ('Papillon-Poodle Mix', 3),
#  ('Chihuahua-Shiba Inu Mix', 3),
#  ('American Staffordshire Terrier-German Shepherd Dog Mix', 3),
#  ('Poodle-Pomeranian Mix', 3),
#  ('Australian Shepherd Mix', 3),
#  ('Airedale Terrier-Labrador Retriever Mix', 3),
#  ('Labrador Retriever-Bull Terrier Mix', 3),
#  ('Labrador Retriever-St. Bernard Mix', 3),
#  ('Pug-Lhasa Apso Mix', 3),
#  ('German Shepherd Dog-Redbone Coonhound Mix', 3),
#  ('Dachshund-Doberman Pinscher Mix', 3),
#  ('Scottish Deerhound', 3),
#  ('American Pit Bull Terrier-Mastiff Mix', 3),
#  ('Dachshund-Pug Mix', 3),
#  ('Old English Sheepdog-Poodle Mix', 3),
#  ('American Staffordshire Terrier-Bullmastiff Mix', 3),
#  ('English Springer Spaniel-Border Collie Mix', 3),
#  ('Collie- Mix', 3),
#  ('Boxer Mix', 3),
#  ('Staffordshire Bull Terrier-Border Collie Mix', 3),
#  ('Bernese Mountain Dog-Poodle Mix', 3),
#  ('Australian Shepherd-Rottweiler Mix', 3),
#  ('Bulldog-American Pit Bull Terrier Mix', 3),
#  ('Shih Tzu Mix', 3),
#  ('Siberian Husky-American Pit Bull Terrier Mix', 3),
#  ('Shih Tzu- Mix', 3),
#  ('Boston Terrier-Pug Mix', 3),
#  ('Golden Retriever- Mix', 3),
#  ('Shih Tzu-Pomeranian Mix', 3),
#  ('Cocker Spaniel-Bichon Frise Mix', 3),
#  ('Chow Chow-German Shepherd Dog Mix', 3),
#  ('Maltese-Pomeranian Mix', 3),
#  ('Miniature Schnauzer- Mix', 3),
#  ('Chihuahua-Poodle Mix', 3),
#  ('English Springer Spaniel-Labrador Retriever Mix', 3),
#  ('Havanese-Maltese Mix', 3),
#  ('Border Collie-Brittany Mix', 3),
#  ('Labrador Retriever-Doberman Pinscher Mix', 3),
#  ('Karelian Bear Dog', 3),
#  ('Irish Setter-Poodle Mix', 3),
#  ('Labrador Retriever-Bloodhound Mix', 3),
#  ('German Shepherd Dog-Akita Mix', 3),
#  ('Parson Russell Terrier-Russell Terrier Mix', 3),
#  ('French Bulldog-Pug Mix', 3),
#  ('Rottweiler-Siberian Husky Mix', 3),
#  ('Golden Retriever-Beagle Mix', 3),
#  ('Beagle-Pekingese Mix', 3),
#  ('Beagle-German Shepherd Dog Mix', 3),
#  ('Pug-Brussels Griffon Mix', 3),
#  ('Golden Retriever-Australian Shepherd Mix', 3),
#  ('Rat Terrier-Beagle Mix', 3),
#  ('Siberian Husky-Rottweiler Mix', 3),
#  ('Parson Russell Terrier-Poodle Mix', 3),
#  ('American Pit Bull Terrier-Bullmastiff Mix', 3),
#  ('Parson Russell Terrier-Rat Terrier Mix', 3),
#  ('Border Terrier-Lakeland Terrier Mix', 3),
#  ('Staffordshire Bull Terrier-Labrador Retriever Mix', 3),
#  ('Thai Ridgeback', 3),
#  ('Golden Retriever-St. Bernard Mix', 3),
#  ('American Pit Bull Terrier-Siberian Husky Mix', 3),
#  ('West Highland White Terrier-Bichon Frise Mix', 3),
#  ('Maltese-Chihuahua Mix', 3),
#  ('Airedale Terrier-Golden Retriever Mix', 3),
#  ('Bernese Mountain Dog-Labrador Retriever Mix', 3),
#  ('Labrador Retriever-Vizsla Mix', 3),
#  ('English Springer Spaniel-Cocker Spaniel Mix', 3),
#  ('American Pit Bull Terrier-Bull Terrier Mix', 3),
#  ('Pomeranian-Papillon Mix', 3),
#  ('Rhodesian Ridgeback-American Pit Bull Terrier Mix', 3),
#  ('Russell Terrier-Rat Terrier Mix', 3),
#  ('Poodle-German Shepherd Dog Mix', 3),
#  ('Beagle-Bulldog Mix', 3),
#  ('Bull Terrier-Labrador Retriever Mix', 3),
#  ('Beagle-Chihuahua Mix', 3),
#  ('Siberian Husky-American Staffordshire Terrier Mix', 3),
#  ('Pembroke Welsh Corgi-Chihuahua Mix', 3),
#  ('Boxer-Mastiff Mix', 3),
#  ('Border Terrier-Parson Russell Terrier Mix', 3),
#  ('Staffordshire Bull Terrier-Bullmastiff Mix', 3),
#  ('Borzoi-Whippet Mix', 3),
#  ('Bloodhound-Black and Tan Coonhound Mix', 3),
#  ('Belgian Malinois-German Shepherd Dog Mix', 3),
#  ('Beagle-Golden Retriever Mix', 3),
#  ('Great Pyrenees-Labrador Retriever Mix', 3),
#  ('Lhasa Apso-Maltese Mix', 3),
#  ('Great Pyrenees-Golden Retriever Mix', 3),
#  ('Chihuahua-Whippet Mix', 3),
#  ('Chihuahua-Beagle Mix', 3),
#  ('Pug-Boston Terrier Mix', 3),
#  ('Chihuahua-Toy Fox Terrier Mix', 3),
#  ('American Pit Bull Terrier-Beagle Mix', 3),
#  ('Beagle-Cocker Spaniel Mix', 3),
#  ('Beagle-Parson Russell Terrier Mix', 3),
#  ('Chihuahua-Boston Terrier Mix', 3),
#  ('Shih Tzu-Brussels Griffon Mix', 3),
#  ('Boxer-Staffordshire Bull Terrier Mix', 3),
#  ('Doberman Pinscher-Rottweiler Mix', 3),
#  ('Siberian Husky-Boxer Mix', 3),
#  ('Jack Russell Terrier-Beagle Mix', 3),
#  ('Siberian Husky-Staffordshire Bull Terrier Mix', 3),
#  ('Staffordshire Bull Terrier-Australian Kelpie Mix', 3),
#  ('Dachshund-Basset Hound Mix', 3),
#  ('Poodle-Australian Cattle Dog Mix', 3),
#  ('Border Collie-Great Pyrenees Mix', 3),
#  ('German Shepherd Dog-Collie Mix', 3),
#  ('Alaskan Malamute-Labrador Retriever Mix', 3),
#  ('Australian Shepherd-Standard Poodle Mix', 3),
#  ('Australian Kelpie-Staffordshire Bull Terrier Mix', 3),
#  ('Rottweiler-Collie Mix', 3),
#  ('Jack Russell Terrier-American Pit Bull Terrier Mix', 3),
#  ('Greyhound-Border Collie Mix', 3),
#  ('Labrador Retriever-Standard Poodle Mix', 3),
#  ('Collie-Shetland Sheepdog Mix', 2),
#  ('Silky Terrier-Poodle Mix', 2),
#  ('Russell Terrier-Miniature Pinscher Mix', 2),
#  ('Staffordshire Bull Terrier-Bulldog Mix', 2),
#  ('Labrador Retriever-Basenji Mix', 2),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix', 2),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix', 2),
#  ('Border Terrier- Mix', 2),
#  ('Boston Terrier-Bulldog Mix', 2),
#  ('Poodle-Old English Sheepdog Mix', 2),
#  ('German Shorthaired Pointer-Catahoula Leopard Dog Mix', 2),
#  ('Golden Retriever-Newfoundland Mix', 2),
#  ('Beagle- Mix', 2),
#  ('Pug-Wire Fox Terrier Mix', 2),
#  ('Chinese Crested-Poodle Mix', 2),
#  ('Boxer-Border Collie Mix', 2),
#  ('Dogue de Bordeaux-Boxer Mix', 2),
#  ('Vizsla- Mix', 2),
#  ('Bulldog-Pug Mix', 2),
#  ('Skye Terrier', 2),
#  ('Labrador Retriever-Treeing Walker Coonhound Mix', 2),
#  ('Boxer-Bloodhound Mix', 2),
#  ('Pekingese-Parson Russell Terrier Mix', 2),
#  ('St. Bernard-Labrador Retriever Mix', 2),
#  ('English Cocker Spaniel-Poodle Mix', 2),
#  ('Beagle-American Eskimo Dog Mix', 2),
#  ('Flat-Coated Retriever- Mix', 2),
#  ('Papillon-Japanese Chin Mix', 2),
#  ('German Shepherd Dog-American Eskimo Dog Mix', 2),
#  ('American Pit Bull Terrier-Boston Terrier Mix', 2),
#  ('Boxer-Vizsla Mix', 2),
#  ('Cairn Terrier-Shih Tzu Mix', 2),
#  ('Boxer-Bull Terrier Mix', 2),
#  ('Italian Greyhound-Russell Terrier Mix', 2),
#  ('Russell Terrier- Mix', 2),
#  ('Otterhound', 2),
#  ('American Staffordshire Terrier-Bull Terrier Mix', 2),
#  ('Border Collie-Saluki Mix', 2),
#  ('Afghan Hound-Airedale Terrier Mix', 2),
#  ('Bull Terrier-Whippet Mix', 2),
#  ('Samoyed-Chow Chow Mix', 2),
#  ('Akita- Mix', 2),
#  ('Schapendoes', 2),
#  ('Parson Russell Terrier-Chihuahua Mix', 2),
#  ('American Pit Bull Terrier-Greyhound Mix', 2),
#  ('Basset Hound-Russell Terrier Mix', 2),
#  ('Newfoundland-Great Pyrenees Mix', 2),
#  ('Labrador Retriever-Flat-Coated Retriever Mix', 2),
#  ('Beagle-Pointer Mix', 2),
#  ('Dachshund-Parson Russell Terrier Mix', 2),
#  ('Border Collie-American Eskimo Dog Mix', 2),
#  ('Portuguese Pointer', 2),
#  ('Golden Retriever-Basset Hound Mix', 2),
#  ('Basset Hound-German Shepherd Dog Mix', 2),
#  ('Whippet-Russell Terrier Mix', 2),
#  ('Boxer- Mix', 2),
#  ('Keeshond-Chow Chow Mix', 2),
#  ('Akita-Siberian Husky Mix', 2),
#  ('Rhodesian Ridgeback-American Staffordshire Terrier Mix', 2),
#  ('Beagle-Siberian Husky Mix', 2),
#  ('Poodle-Rat Terrier Mix', 2),
#  ('Miniature Pinscher- Mix', 2),
#  ('Australian Cattle Dog-Rottweiler Mix', 2),
#  ('Havanese-Pekingese Mix', 2),
#  ('Jindo-German Shepherd Dog Mix', 2),
#  ('Border Collie-Rottweiler Mix', 2),
#  ('Dalmatian-American Pit Bull Terrier Mix', 2),
#  ('German Shepherd Dog-Mastiff Mix', 2),
#  ('Rhodesian Ridgeback-Redbone Coonhound Mix', 2),
#  ('American Pit Bull Terrier-German Shepherd Dog Mix', 2),
#  ('Dachshund-Cocker Spaniel Mix', 2),
#  ('Poodle-German Spitz Mix', 2),
#  ('Parson Russell Terrier- Mix', 2),
#  ('Siberian Husky- Mix', 2),
#  ('Chihuahua Mix', 2),
#  ('Bull Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('Anatolian Shepherd Dog Mix', 2),
#  ('Golden Retriever Mix', 2),
#  ('Cocker Spaniel-Golden Retriever Mix', 2),
#  ('Mastiff-American Pit Bull Terrier Mix', 2),
#  ('Chihuahua-Cardigan Welsh Corgi Mix', 2),
#  ('Beagle-American Foxhound Mix', 2),
#  ('Pug-Chinese Shar-Pei Mix', 2),
#  ('Chihuahua-Smooth Fox Terrier Mix', 2),
#  ('Border Collie-Irish Setter Mix', 2),
#  ('Poodle-Russell Terrier Mix', 2),
#  ('Border Collie-Poodle Mix', 2),
#  ('Boxer-Siberian Husky Mix', 2),
#  ('Russell Terrier-Cocker Spaniel Mix', 2),
#  ('Catahoula Leopard Dog-Border Collie Mix', 2),
#  ('Dachshund- Mix', 2),
#  ('Maltese- Mix', 2),
#  ('Lhasa Apso- Mix', 2),
#  ('Chihuahua-Parson Russell Terrier Mix', 2),
#  ('Dalmatian-Labrador Retriever Mix', 2),
#  ('Russell Terrier Mix', 2),
#  ('Basset Hound-American Pit Bull Terrier Mix', 2),
#  ('Shih Tzu-Dachshund Mix', 2),
#  ('Boxer-Dutch Shepherd Mix', 2),
#  ('Boston Terrier-Beagle Mix', 2),
#  ('Cairn Terrier-Yorkshire Terrier Mix', 2),
#  ('Rat Terrier-Dachshund Mix', 2),
#  ('Alaskan Malamute- Mix', 2),
#  ('Akita-Affenpinscher Mix', 2),
#  ('Rottweiler-Rhodesian Ridgeback Mix', 2),
#  ('German Shepherd Dog-Staffordshire Bull Terrier Mix', 2),
#  ('Shih Tzu-Silky Terrier Mix', 2),
#  ('Flat-Coated Retriever-Border Collie Mix', 2),
#  ('Border Collie-Beagle Mix', 2),
#  ('German Shorthaired Pointer-American Pit Bull Terrier Mix', 2),
#  ('Australian Shepherd-Beagle Mix', 2),
#  ('Border Collie-Boxer Mix', 2),
#  ('Miniature Pinscher-Shih Tzu Mix', 2),
#  ('Australian Shepherd-Alaskan Malamute Mix', 2),
#  ('American Eskimo Dog-Golden Retriever Mix', 2),
#  ('Bullmastiff-Chinese Shar-Pei Mix', 2),
#  ('Chow Chow-Collie Mix', 2),
#  ('Standard Schnauzer-Yorkshire Terrier Mix', 2),
#  ('Australian Shepherd-Doberman Pinscher Mix', 2),
#  ('Maltese-Lhasa Apso Mix', 2),
#  ('Labrador Retriever-Dalmatian Mix', 2),
#  ('Rat Terrier-Parson Russell Terrier Mix', 2),
#  ('Golden Retriever-Pembroke Welsh Corgi Mix', 2),
#  ('American Staffordshire Terrier-Chinese Shar-Pei Mix', 2),
#  ('Pomeranian-Pekingese Mix', 2),
#  ('Chihuahua-Cairn Terrier Mix', 2),
#  ('Boxer-Dalmatian Mix', 2),
#  ('Akita-Afghan Hound Mix', 2),
#  ('German Shepherd Dog-Whippet Mix', 2),
#  ('Smooth Fox Terrier-Whippet Mix', 2),
#  ('Bichon Frise-West Highland White Terrier Mix', 2),
#  ('Greyhound-Saluki Mix', 2),
#  ('Brittany-English Springer Spaniel Mix', 2),
#  ('St. Bernard-Border Collie Mix', 2),
#  ('Belgian Malinois-Dutch Shepherd Mix', 2),
#  ('Cirneco dell"Etna', 2),
#  ('Dachshund-Russell Terrier Mix', 2),
#  ('Bernese Mountain Dog-Border Collie Mix', 2),
#  ('Greyhound-Whippet Mix', 2),
#  ('Cavalier King Charles Spaniel Mix', 2),
#  ('Poodle-Border Collie Mix', 2),
#  ('Greyhound-Staffordshire Bull Terrier Mix', 2),
#  ('Chihuahua-Maltese Mix', 2),
#  ('Pekingese-Pomeranian Mix', 2),
#  ('Maltese Mix', 2),
#  ('Russell Terrier-Yorkshire Terrier Mix', 2),
#  ('Chinese Shar-Pei-Boerboel Mix', 2),
#  ('Havanese-Shih Tzu Mix', 2),
#  ('Yorkshire Terrier-Cairn Terrier Mix', 2),
#  ('Pug- Mix', 2),
#  ('Border Collie-Belgian Sheepdog Mix', 2),
#  ('Border Collie-Field Spaniel Mix', 2),
#  ('Russell Terrier-Wire Fox Terrier Mix', 2),
#  ('Cairn Terrier-West Highland White Terrier Mix', 2),
#  ('Maltese-Silky Terrier Mix', 2),
#  ('Cardigan Welsh Corgi-Russell Terrier Mix', 2),
#  ('West Highland White Terrier-Lhasa Apso Mix', 2),
#  ('Shetland Sheepdog-Australian Cattle Dog Mix', 2),
#  ('Bulldog-Bullmastiff Mix', 2),
#  ('Golden Retriever-Cocker Spaniel Mix', 2),
#  ('Australian Cattle Dog-Bluetick Coonhound Mix', 2),
#  ('American Foxhound-Labrador Retriever Mix', 2),
#  ('Siberian Husky-Rhodesian Ridgeback Mix', 2),
#  ('American Eskimo Dog-Australian Shepherd Mix', 2),
#  ('Shih Tzu-Russell Terrier Mix', 2),
#  ('Boxer-Jindo Mix', 2),
#  ('German Shepherd Dog-Shiba Inu Mix', 2),
#  ('Pekingese-Tibetan Spaniel Mix', 2),
#  ('Australian Cattle Dog-Cocker Spaniel Mix', 2),
#  ('Siberian Husky-Standard Schnauzer Mix', 2),
#  ('Anatolian Shepherd Dog-Great Pyrenees Mix', 2),
#  ('Belgian Malinois-Siberian Husky Mix', 2),
#  ('Chihuahua-Labrador Retriever Mix', 2),
#  ('Miniature Schnauzer-Cairn Terrier Mix', 2),
#  ('Bernese Mountain Dog-Rottweiler Mix', 2),
#  ('Miniature Schnauzer-Shih Tzu Mix', 2),
#  ('Border Collie-Chow Chow Mix', 2),
#  ('German Shepherd Dog-American Staffordshire Terrier Mix', 2),
#  ('Pomeranian-Shih Tzu Mix', 2),
#  ('Flat-Coated Retriever-Labrador Retriever Mix', 2),
#  ('American Staffordshire Terrier-Rhodesian Ridgeback Mix', 2),
#  ('Boxer-Akita Mix', 2),
#  ('Shetland Sheepdog-Collie Mix', 2),
#  ('Lhasa Apso-Bichon Frise Mix', 2),
#  ('Belgian Malinois-Chow Chow Mix', 2),
#  ('West Highland White Terrier-Dachshund Mix', 2),
#  ('Shih Tzu-Coton de Tulear Mix', 2),
#  ('Affenpinscher-Poodle Mix', 2),
#  ('Mastador', 2),
#  ('Brussels Griffon-Pug Mix', 2),
#  ('Siberian Husky-Beagle Mix', 2),
#  ('Boxer-Australian Cattle Dog Mix', 2),
#  ('Australian Cattle Dog-Catahoula Leopard Dog Mix', 2),
#  ('Standard Schnauzer-Poodle Mix', 2),
#  ('Beagle-Poodle Mix', 2),
#  ('American Staffordshire Terrier-Dogo Argentino Mix', 2),
#  ('Siberian Husky-Alaskan Malamute Mix', 2),
#  ('German Shepherd Dog-Keeshond Mix', 2),
#  ('Greyhound-American Pit Bull Terrier Mix', 2),
#  ('English Springer Spaniel-Dalmatian Mix', 2),
#  ('Lancashire Heeler-Australian Cattle Dog Mix', 2),
#  ('Siberian Husky-Chow Chow Mix', 2),
#  ('Australian Shepherd-Cocker Spaniel Mix', 2),
#  ('Maltese-Cavalier King Charles Spaniel Mix', 2),
#  ('Bichon Frise-Cocker Spaniel Mix', 2),
#  ('Maltese-Havanese Mix', 2),
#  ('Australian Cattle Dog-Boxer Mix', 2),
#  ('Beagle-Treeing Walker Coonhound Mix', 2),
#  ('Bullmastiff-Labrador Retriever Mix', 2),
#  ('Russell Terrier-Toy Fox Terrier Mix', 2),
#  ('Catahoula Leopard Dog-Australian Shepherd Mix', 2),
#  ('American Staffordshire Terrier-Golden Retriever Mix', 2),
#  ('Russell Terrier-Australian Cattle Dog Mix', 2),
#  ('Redbone Coonhound-German Shepherd Dog Mix', 2),
#  ('Pembroke Welsh Corgi-Australian Cattle Dog Mix', 2),
#  ('Plott-Beagle Mix', 2),
#  ('Italian Greyhound-Miniature Pinscher Mix', 2),
#  ('Labrador Retriever-Catahoula Leopard Dog Mix', 2),
#  ('Papillon-Chihuahua Mix', 2),
#  ('Tosa', 2),
#  ('Pomeranian-Rat Terrier Mix', 2),
#  ('Labrador Retriever-Rhodesian Ridgeback Mix', 2),
#  ('Poodle-Australian Shepherd Mix', 2),
#  ('Great Pyrenees-Australian Cattle Dog Mix', 2),
#  ('Rat Terrier-Basenji Mix', 2),
#  ('American Staffordshire Terrier-Mastiff Mix', 2),
#  ('German Shepherd Dog-Shetland Sheepdog Mix', 2),
#  ('Chesapeake Bay Retriever-Siberian Husky Mix', 2),
#  ('Boxer-Boston Terrier Mix', 2),
#  ('Shih Tzu-Pug Mix', 2),
#  ('Australian Cattle Dog-Greyhound Mix', 2),
#  ('Pomeranian-Maltese Mix', 2),
#  ('Karelian Bear Dog-Border Collie Mix', 2),
#  ('Barbet', 2),
#  ('Boston Terrier-Pomeranian Mix', 2),
#  ('Havanese-Lhasa Apso Mix', 2),
#  ('Labrador Retriever-Great Pyrenees Mix', 2),
#  ('Chinese Crested-Papillon Mix', 2),
#  ('Great Dane-Mastiff Mix', 2),
#  ('Bluetick Coonhound-Beagle Mix', 2),
#  ('Havanese-Coton de Tulear Mix', 2),
#  ('Siberian Husky-Shiba Inu Mix', 2),
#  ('American Staffordshire Terrier-Dogue de Bordeaux Mix', 2),
#  ('Miniature Schnauzer-Wire Fox Terrier Mix', 2),
#  ('Catahoula Leopard Dog-Bluetick Coonhound Mix', 2),
#  ('Border Collie-Pomeranian Mix', 2),
#  ('Chinese Shar-Pei-German Shepherd Dog Mix', 2),
#  ('American English Coonhound', 2),
#  ('Black and Tan Coonhound-Labrador Retriever Mix', 2),
#  ('Papillon-Pomeranian Mix', 2),
#  ('Shetland Sheepdog-Australian Shepherd Mix', 2),
#  ('Chihuahua-Shih Tzu Mix', 2),
#  ('Whippet-Border Collie Mix', 2),
#  ('Cardigan Welsh Corgi-American Pit Bull Terrier Mix', 2),
#  ('Beagle-Boston Terrier Mix', 2),
#  ('Plott-Labrador Retriever Mix', 2),
#  ('Jack Russell Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('Great Dane-American Staffordshire Terrier Mix', 2),
#  ('Australian Kelpie-Labrador Retriever Mix', 2),
#  ('Beagle-Collie Mix', 2),
#  ('Border Collie-Great Dane Mix', 2),
#  ('American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('Jack Russell Terrier-Cavalier King Charles Spaniel Mix', 2),
#  ('Whippet-Greyhound Mix', 2),
#  ('Dalmatian-Beagle Mix', 2),
#  ('Labrador Retriever-Bulldog Mix', 2),
#  ('Sealyham Terrier', 2),
#  ('Weimaraner-American Pit Bull Terrier Mix', 2),
#  ('West Highland White Terrier-Poodle Mix', 2),
#  ('Saluki-Greyhound Mix', 2),
#  ('Jack Russell Terrier-Welsh Terrier Mix', 2),
#  ('Australian Cattle Dog-Bull Terrier Mix', 2),
#  ('German Shepherd Dog-Norwegian Elkhound Mix', 2),
#  ('Cavalier King Charles Spaniel-Coton de Tulear Mix', 2),
#  ('Lancashire Heeler', 2),
#  ('American Pit Bull Terrier-Vizsla Mix', 2),
#  ('Siberian Husky-Greyhound Mix', 2),
#  ('Staffordshire Bull Terrier-Beagle Mix', 2),
#  ('Giant Schnauzer-Standard Poodle Mix', 2),
#  ('American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('Poodle-English Cocker Spaniel Mix', 2),
#  ('Siberian Husky-Keeshond Mix', 2),
#  ('English Springer Spaniel-Jack Russell Terrier Mix', 2),
#  ('Boxer-Bullmastiff Mix', 2),
#  ('German Shorthaired Pointer-Pointer Mix', 2),
#  ('Yorkshire Terrier-Pekingese Mix', 2),
#  ('Shetland Sheepdog-American Eskimo Dog Mix', 2),
#  ('Brittany-Labrador Retriever Mix', 2),
#  ('Bearded Collie-Border Collie Mix', 2),
#  ('Kuvasz', 2),
#  ('English Setter-Labrador Retriever Mix', 2),
#  ('Maltese-West Highland White Terrier Mix', 2),
#  ('Staffordshire Bull Terrier-Whippet Mix', 2),
#  ('Pug-American Pit Bull Terrier Mix', 2),
#  ('American Leopard Hound', 2),
#  ('Miniature Schnauzer-Chihuahua Mix', 2),
#  ('Chihuahua-Australian Terrier Mix', 2),
#  ('American Pit Bull Terrier-Whippet Mix', 2),
#  ('Great Dane-Rottweiler Mix', 2),
#  ('Caucasian Ovcharka', 2),
#  ('German Shepherd Dog-Belgian Sheepdog Mix', 2),
#  ('Jack Russell Terrier-Shih Tzu Mix', 2),
#  ('Pug-Cavalier King Charles Spaniel Mix', 2),
#  ('Dachshund-American Pit Bull Terrier Mix', 2),
#  ('German Shepherd Dog-Basset Hound Mix', 2),
#  ('Portuguese Podengo Pequeno-Jack Russell Terrier Mix', 2),
#  ('Golden Retriever-Standard Poodle Mix', 2),
#  ('Poodle-Havanese Mix', 2),
#  ('Standard Poodle-Soft Coated Wheaten Terrier Mix', 2),
#  ('German Shepherd Dog-Australian Kelpie Mix', 2),
#  ('Great Dane-Bullmastiff Mix', 2),
#  ('German Shorthaired Pointer-Rottweiler Mix', 2),
#  ('Jack Russell Terrier-Poodle Mix', 2),
#  ('Staffordshire Bull Terrier-Bull Terrier Mix', 2),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', 1),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 1),
#  ('Parson Russell Terrier-Beagle Mix', 1),
#  ('English Cocker Spaniel-Cocker Spaniel Mix', 1),
#  ('Beagle-Schipperke Mix', 1),
#  ('American Eskimo Dog-Papillon Mix', 1),
#  ('German Shepherd Dog-Belgian Tervuren Mix', 1),
#  ('Canaan Dog- Mix', 1),
#  ('Russell Terrier-Pug Mix', 1),
#  ('Labrador Retriever-Cane Corso Mix', 1),
#  ('Brittany-Poodle Mix', 1),
#  ('Bearded Collie-Tibetan Terrier Mix', 1),
#  ('Belgian Sheepdog- Mix', 1),
#  ('Border Collie-Belgian Tervuren Mix', 1),
#  ('American Staffordshire Terrier-Australian Shepherd Mix', 1),
#  ('Pekingese-Dachshund Mix', 1),
#  ('Rottweiler- Mix', 1),
#  ('Pug-Maltese Mix', 1),
#  ('Alaskan Malamute-Collie Mix', 1),
#  ('Staffordshire Bull Terrier-Great Dane Mix', 1),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix', 1),
#  ('Pug-Smooth Fox Terrier Mix', 1),
#  ('Bearded Collie-Beagle Mix', 1),
#  ('Catahoula Leopard Dog-Rottweiler Mix', 1),
#  ('Great Dane-Irish Wolfhound Mix', 1),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix', 1),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix', 1),
#  ('Afghan Hound-Golden Retriever Mix', 1),
#  ('Chihuahua-American Staffordshire Terrier Mix', 1),
#  ('Whippet-Chinese Shar-Pei Mix', 1),
#  ('Cocker Spaniel-Doberman Pinscher Mix', 1),
#  ('Rat Terrier-Cavalier King Charles Spaniel Mix', 1),
#  ('Rat Terrier-Miniature Pinscher Mix', 1),
#  ('Plott-Border Collie Mix', 1),
#  ('French Bulldog-Bulldog Mix', 1),
#  ('Boxer-Cocker Spaniel Mix', 1),
#  ('Labrador Retriever-American Foxhound Mix', 1),
#  ('Mastiff-St. Bernard Mix', 1),
#  ('Chow Chow-Norfolk Terrier Mix', 1),
#  ('Rhodesian Ridgeback-Weimaraner Mix', 1),
#  ('English Springer Spaniel- Mix', 1),
#  ('Chinese Shar-Pei-Pug Mix', 1),
#  ('Maltese-Japanese Chin Mix', 1),
#  ('Basenji-Russell Terrier Mix', 1),
#  ('Chinese Crested-Pug Mix', 1),
#  ('American Staffordshire Terrier-Portuguese Podengo Mix', 1),
#  ('Staffordshire Bull Terrier-Boston Terrier Mix', 1),
#  ('Mudi-Australian Cattle Dog Mix', 1),
#  ('American Eskimo Dog-Russell Terrier Mix', 1),
#  ('Pointer-Beagle Mix', 1),
#  ('Collie Mix', 1),
#  ('Pembroke Welsh Corgi-American Eskimo Dog Mix', 1),
#  ('Redbone Coonhound-Vizsla Mix', 1),
#  ('Rottweiler-Redbone Coonhound Mix', 1),
#  ('Chow Chow-Cocker Spaniel Mix', 1),
#  ('Dachshund-Boston Terrier Mix', 1),
#  ('Golden Retriever-English Cocker Spaniel Mix', 1),
#  ('Shiba Inu-Pembroke Welsh Corgi Mix', 1),
#  ('Russell Terrier-Poodle Mix', 1),
#  ('Redbone Coonhound-Bloodhound Mix', 1),
#  ('Boykin Spaniel-Deutscher Wachtelhund Mix', 1),
#  ('Italian Greyhound-Cardigan Welsh Corgi Mix', 1),
#  ('Doberman Pinscher-Black and Tan Coonhound Mix', 1),
#  ('Chinese Shar-Pei-Labrador Retriever Mix', 1),
#  ('Pomeranian-Basenji Mix', 1),
#  ('Portuguese Podengo Pequeno', 1),
#  ('Australian Shepherd-Shih Tzu Mix', 1),
#  ('Boxer-Ibizan Hound Mix', 1),
#  ('Doberman Pinscher-Greyhound Mix', 1),
#  ('Chesapeake Bay Retriever-Beagle Mix', 1),
#  ('Border Terrier-Shih Tzu Mix', 1),
#  ('Redbone Coonhound-Rhodesian Ridgeback Mix', 1),
#  ('Catahoula Leopard Dog-Plott Mix', 1),
#  ('Australian Cattle Dog-Curly-Coated Retriever Mix', 1),
#  ('Maltese-Cocker Spaniel Mix', 1),
#  ('Staffordshire Bull Terrier-Russell Terrier Mix', 1),
#  ...]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT gender ,breed_group, count(distinct dog_guid) as number
# from dogs
# group by 2, 1
# order by 3 desc
# Out:
# 18 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075),
#  ('female', 'Non-Sporting', 919),
#  ('male', 'Terrier', 919),
#  ('female', 'Working', 895),
#  ('female', 'Terrier', 794),
#  ('male', 'Hound', 725),
#  ('female', 'Hound', 614),
#  ('male', '', 147),
#  ('female', '', 127)]

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT gender ,breed_group, count(distinct dog_guid) as num_coun
# from dogs
# where breed_group!=""
# group by 2, 1
# having num_coun >= 1000
# order by 3 desc
# Out:
# 8 rows affected.
# [('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075)]

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %%sql
# select avg(total_tests_completed) as avg_complete, avg(mean_iti_minutes) as avg_interval,breed_type from dogs
# group by 3
# order by 1 desc
# Out:
# 4 rows affected.
# [(10.257530120481928, 2834.3205728931534, 'Popular Hybrid'),
#  (9.945900537634408, 2872.351156110182, 'Cross Breed'),
#  (9.871602824737856, 3193.350493795222, 'Pure Breed'),
#  (9.54250850170034, 3023.0711302156274, "Mixed Breed/ Other/ I Don't Know")]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# select test_name, avg(timestampdiff(hour,start_time,end_time)) as avg_time from exam_answers
# where timestampdiff(hour,start_time,end_time) < 6000
# group by test_name
# having avg(timestampdiff(second,start_time,end_time)) > 0
# Out:
# 67 rows affected.
# [('1 vs 1 Game', Decimal('0.0000')),
#  ('3 vs 1 Game', Decimal('0.0000')),
#  ('5 vs 1 Game', Decimal('0.0000')),
#  ('Activity', Decimal('20.0071')),
#  ('Arm Pointing', Decimal('0.6092')),
#  ('Attachment', Decimal('11.0557')),
#  ('Confinement', Decimal('9.2003')),
#  ('Cover Your Eyes', Decimal('0.8247')),
#  ('Delayed Cup Game', Decimal('1.4267')),
#  ('Diet', Decimal('32.7712')),
#  ('Different Perspective', Decimal('0.0493')),
#  ('Emotions', Decimal('4.6607')),
#  ('Environment', Decimal('0.4971')),
#  ('Excitability', Decimal('10.9972')),
#  ('Expression Game', Decimal('0.0000')),
#  ('Eye Contact Game', Decimal('1.1389')),
#  ('Eye Contact Warm-up', Decimal('1.2267')),
#  ('Foot Pointing', Decimal('0.5739')),
#  ('Gender', Decimal('6.1326')),
#  ('Impossible Task Game', Decimal('0.1913')),
#  ('Impossible Task Warm-up', Decimal('3.8022')),
#  ('Inferential Reasoning Game', Decimal('0.3883')),
#  ('Inferential Reasoning Warm-up', Decimal('1.3832')),
#  ('Memory versus Pointing', Decimal('0.2205')),
#  ('Memory versus Smell', Decimal('1.1865')),
#  ('Navigation Game', Decimal('0.1273')),
#  ('Navigation Learning', Decimal('0.2271')),
#  ('Navigation Warm-up', Decimal('6.1733')),
#  ('Numerosity Warm-Up', Decimal('4.5937')),
#  ('Obedience', Decimal('3.4643')),
#  ('One Cup Warm-up', Decimal('1.4191')),
#  ('Owner', Decimal('5.2280')),
#  ('Partnership', Decimal('3.4735')),
#  ('Perception', Decimal('3.8185')),
#  ('Physical', Decimal('5.6950')),
#  ('Physical Reasoning Game', Decimal('0.0819')),
#  ('Physical Reasoning Warm-up', Decimal('0.4921')),
#  ('Purina', Decimal('2.4655')),
#  ('Purina-Only', Decimal('3.3696')),
#  ('Puzzles', Decimal('3.7676')),
#  ('Recall', Decimal('3.8206')),
#  ('Self Control Game', Decimal('0.0000')),
#  ('Set 1', Decimal('3.0899')),
#  ('Set 2', Decimal('0.1259')),
#  ('Set 3', Decimal('7.0007')),
#  ('Shaker Game', Decimal('0.0000')),
#  ('Shaker Warm-Up', Decimal('0.0644')),
#  ('Shared Perspective', Decimal('0.0000')),
#  ('Shy/Boldness', Decimal('11.6170')),
#  ('Slide', Decimal('0.5362')),
#  ('Smell Game', Decimal('1.1813')),
#  ('Sociability', Decimal('21.1726')),
#  ('Social', Decimal('2.7286')),
#  ('Social-Quiz', Decimal('81.9923')),
#  ('Stair Game', Decimal('0.3021')),
#  ('Surprise And Delight', Decimal('10.9355')),
#  ('Switch', Decimal('0.0531')),
#  ('Toys', Decimal('2.2110')),
#  ('Training', Decimal('2.6089')),
#  ('Treat Warm-up', Decimal('2.2185')),
#  ('Turn Your Back', Decimal('0.7646')),
#  ('Two Cup Warm-up', Decimal('0.1223')),
#  ('Warm-Up', Decimal('2.0840')),
#  ('Watching', Decimal('11.4743')),
#  ('Watching - Part 2', Decimal('2.1875')),
#  ('Yawn Game', Decimal('3.8349')),
#  ('Yawn Warm-up', Decimal('15.2669'))]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %%sql
# select count(distinct user_guid), zip, state from users
# where country = "US"
# group by state, zip
# order by state asc, count(distinct user_guid) desc
# Out:
# 5043 rows affected.
# [(2, '9128', 'AE'),
#  (1, '9469', 'AE'),
#  (1, '9845', 'AE'),
#  (1, '9053', 'AE'),
#  (1, '9107', 'AE'),
#  (3, '99507', 'AK'),
#  (3, '99709', 'AK'),
#  (2, '99577', 'AK'),
#  (2, '99501', 'AK'),
#  (1, '99928', 'AK'),
#  (1, '99587', 'AK'),
#  (1, '99611', 'AK'),
#  (1, '99645', 'AK'),
#  (1, '99676', 'AK'),
#  (1, '99502', 'AK'),
#  (1, '99705', 'AK'),
#  (1, '99509', 'AK'),
#  (1, '99712', 'AK'),
#  (1, '99516', 'AK'),
#  (1, '99752', 'AK'),
#  (1, '99518', 'AK'),
#  (1, '99775', 'AK'),
#  (1, '99567', 'AK'),
#  (1, '99824', 'AK'),
#  (4, '35209', 'AL'),
#  (2, '36609', 'AL'),
#  (2, '36116', 'AL'),
#  (2, '35801', 'AL'),
#  (2, '36532', 'AL'),
#  (1, '35976', 'AL'),
#  (1, '36602', 'AL'),
#  (1, '35476', 'AL'),
#  (1, '36037', 'AL'),
#  (1, '35004', 'AL'),
#  (1, '36604', 'AL'),
#  (1, '35646', 'AL'),
#  (1, '36104', 'AL'),
#  (1, '35007', 'AL'),
#  (1, '35662', 'AL'),
#  (1, '36106', 'AL'),
#  (1, '35094', 'AL'),
#  (1, '36695', 'AL'),
#  (1, '35674', 'AL'),
#  (1, '35121', 'AL'),
#  (1, '36801', 'AL'),
#  (1, '35758', 'AL'),
#  (1, '36203', 'AL'),
#  (1, '35179', 'AL'),
#  (1, '36832', 'AL'),
#  (1, '35760', 'AL'),
#  (1, '36303', 'AL'),
#  (1, '35205', 'AL'),
#  (1, '35763', 'AL'),
#  (1, '36375', 'AL'),
#  (1, '36527', 'AL'),
#  (1, '35216', 'AL'),
#  (1, '35803', 'AL'),
#  (1, '35242', 'AL'),
#  (1, '35906', 'AL'),
#  (1, '36561', 'AL'),
#  (1, '35405', 'AL'),
#  (1, '96205', 'AP'),
#  (1, '96310', 'AP'),
#  (1, '96367', 'AP'),
#  (1, '96377', 'AP'),
#  (3, '72207', 'AR'),
#  (3, '72401', 'AR'),
#  (2, '72712', 'AR'),
#  (2, '72223', 'AR'),
#  (2, '72632', 'AR'),
#  (1, '71913', 'AR'),
#  (1, '72212', 'AR'),
#  (1, '72714', 'AR'),
#  (1, '72015', 'AR'),
#  (1, '72756', 'AR'),
#  (1, '72034', 'AR'),
#  (1, '72762', 'AR'),
#  (1, '72042', 'AR'),
#  (1, '72554', 'AR'),
#  (1, '72802', 'AR'),
#  (1, '72058', 'AR'),
#  (1, '72631', 'AR'),
#  (1, '72901', 'AR'),
#  (1, '72113', 'AR'),
#  (1, '72908', 'AR'),
#  (1, '72135', 'AR'),
#  (1, '72956', 'AR'),
#  (1, '72201', 'AR'),
#  (1, '72701', 'AR'),
#  (1, '72202', 'AR'),
#  (1, '72703', 'AR'),
#  (1, '72206', 'AR'),
#  (1, '72704', 'AR'),
#  (1, '71909', 'AR'),
#  (14, '86303', 'AZ'),
#  (6, '85718', 'AZ'),
#  (5, '85260', 'AZ'),
#  (5, '85711', 'AZ'),
#  (5, '85749', 'AZ'),
#  (5, '85253', 'AZ'),
#  (5, '85254', 'AZ'),
#  (4, '85719', 'AZ'),
#  (4, 'N/A', 'AZ'),
#  (4, '85266', 'AZ'),
#  (4, '85750', 'AZ'),
#  (4, '85716', 'AZ'),
#  (3, '85042', 'AZ'),
#  (3, '85255', 'AZ'),
#  (3, '85044', 'AZ'),
#  (3, '85257', 'AZ'),
#  (3, '85296', 'AZ'),
#  (3, '85737', 'AZ'),
#  (3, '86305', 'AZ'),
#  (3, '85048', 'AZ'),
#  (3, '85233', 'AZ'),
#  (3, '85021', 'AZ'),
#  (3, '85392', 'AZ'),
#  (3, '85022', 'AZ'),
#  (3, '85250', 'AZ'),
#  (3, '85282', 'AZ'),
#  (3, '85283', 'AZ'),
#  (3, '85032', 'AZ'),
#  (2, '85374', 'AZ'),
#  (2, '85045', 'AZ'),
#  (2, '85259', 'AZ'),
#  (2, '85739', 'AZ'),
#  (2, '85304', 'AZ'),
#  (2, '85704', 'AZ'),
#  (2, '85143', 'AZ'),
#  (2, '85745', 'AZ'),
#  (2, '85202', 'AZ'),
#  (2, '85024', 'AZ'),
#  (2, '85748', 'AZ'),
#  (2, '85203', 'AZ'),
#  (2, '85615', 'AZ'),
#  (2, '85712', 'AZ'),
#  (2, '85281', 'AZ'),
#  (2, '85086', 'AZ'),
#  (2, '85028', 'AZ'),
#  (2, '85251', 'AZ'),
#  (2, '85715', 'AZ'),
#  (2, '85206', 'AZ'),
#  (2, '86351', 'AZ'),
#  (1, '85284', 'AZ'),
#  (1, '86002', 'AZ'),
#  (1, '85120', 'AZ'),
#  (1, '85365', 'AZ'),
#  (1, '86403', 'AZ'),
#  (1, '85209', 'AZ'),
#  (1, '85641', 'AZ'),
#  (1, '85013', 'AZ'),
#  (1, '85286', 'AZ'),
#  (1, '86301', 'AZ'),
#  (1, '85122', 'AZ'),
#  (1, '86426', 'AZ'),
#  (1, '85210', 'AZ'),
#  (1, '85646', 'AZ'),
#  (1, '85015', 'AZ'),
#  (1, '85730', 'AZ'),
#  (1, '85128', 'AZ'),
#  (1, '85382', 'AZ'),
#  (1, '86504', 'AZ'),
#  (1, '85212', 'AZ'),
#  (1, '85650', 'AZ'),
#  (1, '85016', 'AZ'),
#  (1, '85303', 'AZ'),
#  (1, '85138', 'AZ'),
#  (1, '85226', 'AZ'),
#  (1, '85658', 'AZ'),
#  (1, '85020', 'AZ'),
#  (1, '86312', 'AZ'),
#  (1, '85140', 'AZ'),
#  (1, '85385', 'AZ'),
#  (1, '85050', 'AZ'),
#  (1, '85262', 'AZ'),
#  (1, '85743', 'AZ'),
#  (1, '85308', 'AZ'),
#  (1, '86314', 'AZ'),
#  (1, '85248', 'AZ'),
#  (1, '85710', 'AZ'),
#  (1, '85069', 'AZ'),
#  (1, '85327', 'AZ'),
#  (1, '86323', 'AZ'),
#  (1, '85614', 'AZ'),
#  (1, '85249', 'AZ'),
#  (1, '85268', 'AZ'),
#  (1, '85083', 'AZ'),
#  (1, '85335', 'AZ'),
#  (1, '86326', 'AZ'),
#  (1, '85027', 'AZ'),
#  (1, '85338', 'AZ'),
#  (1, '86327', 'AZ'),
#  (1, '85205', 'AZ'),
#  (1, '85622', 'AZ'),
#  (1, '85006', 'AZ'),
#  (1, '85118', 'AZ'),
#  (1, '85340', 'AZ'),
#  (1, '86336', 'AZ'),
#  (1, '85635', 'AZ'),
#  (1, '85008', 'AZ'),
#  (1, '85029', 'AZ'),
#  (1, '85755', 'AZ'),
#  (1, '85119', 'AZ'),
#  (1, '85353', 'AZ'),
#  (1, '85207', 'AZ'),
#  (1, '85636', 'AZ'),
#  (1, '85012', 'AZ'),
#  (16, '92107', 'CA'),
#  (13, '90046', 'CA'),
#  (12, '92130', 'CA'),
#  (12, '94107', 'CA'),
#  (10, '94110', 'CA'),
#  (10, '92024', 'CA'),
#  (9, '94941', 'CA'),
#  (9, '94611', 'CA'),
#  (9, '94114', 'CA'),
#  (9, '94025', 'CA'),
#  (8, '90068', 'CA'),
#  (8, '94131', 'CA'),
#  (8, '90069', 'CA'),
#  (8, '90049', 'CA'),
#  (8, '92064', 'CA'),
#  (7, '90292', 'CA'),
#  (7, '90266', 'CA'),
#  (7, '90803', 'CA'),
#  (7, '93003', 'CA'),
#  (7, '94602', 'CA'),
#  (7, '94117', 'CA'),
#  (7, '90278', 'CA'),
#  (7, '94121', 'CA'),
#  (7, '90291', 'CA'),
#  (6, '91301', 'CA'),
#  (6, '94123', 'CA'),
#  (6, '90039', 'CA'),
#  (6, '95762', 'CA'),
#  (6, '92103', 'CA'),
#  (6, '92071', 'CA'),
#  (6, '94901', 'CA'),
#  (6, '95008', 'CA'),
#  (6, '94903', 'CA'),
#  (6, '94952', 'CA'),
#  (6, '95014', 'CA'),
#  (6, '90274', 'CA'),
#  (6, '90277', 'CA'),
#  (6, '94549', 'CA'),
#  (6, '90036', 'CA'),
#  (6, '94061', 'CA'),
#  (6, '92672', 'CA'),
#  (5, '93023', 'CA'),
#  (5, '91406', 'CA'),
#  (5, '94109', 'CA'),
#  (5, '95003', 'CA'),
#  (5, '94597', 'CA'),
#  (5, '90025', 'CA'),
#  (5, '93940', 'CA'),
#  (5, '92106', 'CA'),
#  (5, '95818', 'CA'),
#  (5, '92122', 'CA'),
#  (5, '94904', 'CA'),
#  (5, '92211', 'CA'),
#  (5, '94040', 'CA'),
#  (5, '90210', 'CA'),
#  (5, '90405', 'CA'),
#  (5, '93105', 'CA'),
#  (5, '94118', 'CA'),
#  (5, '93012', 'CA'),
#  (5, '95476', 'CA'),
#  (5, '94550', 'CA'),
#  (5, '94706', 'CA'),
#  (5, '92009', 'CA'),
#  (5, '94510', 'CA'),
#  (5, '90232', 'CA'),
#  (5, '92101', 'CA'),
#  (4, '92116', 'CA'),
#  (4, '92128', 'CA'),
#  (4, '94306', 'CA'),
#  (4, '95616', 'CA'),
#  (4, '92117', 'CA'),
#  (4, '94127', 'CA'),
#  (4, '90720', 'CA'),
#  (4, '94062', 'CA'),
#  (4, '92067', 'CA'),
#  (4, '94403', 'CA'),
#  (4, '92677', 'CA'),
#  (4, '92612', 'CA'),
#  (4, '95401', 'CA'),
#  (4, '91307', 'CA'),
#  (4, '90265', 'CA'),
#  (4, '92649', 'CA'),
#  (4, '95403', 'CA'),
#  (4, '91941', 'CA'),
#  (4, '94501', 'CA'),
#  (4, '90004', 'CA'),
#  (4, '94558', 'CA'),
#  (4, '90026', 'CA'),
#  (4, '92886', 'CA'),
#  (4, '95404', 'CA'),
#  (4, '91942', 'CA'),
#  (4, '92078', 'CA'),
#  (4, '94523', 'CA'),
#  (4, '90027', 'CA'),
#  (4, '90404', 'CA'),
#  (4, '91320', 'CA'),
#  (4, '91367', 'CA'),
#  (4, '92656', 'CA'),
#  (4, '93103', 'CA'),
#  (4, '92109', 'CA'),
#  (4, '94583', 'CA'),
#  (4, '95407', 'CA'),
#  (4, '94703', 'CA'),
#  (4, '90211', 'CA'),
#  (4, '91030', 'CA'),
#  (4, '95472', 'CA'),
#  (4, '94506', 'CA'),
#  (4, '90212', 'CA'),
#  (4, '93561', 'CA'),
#  (4, '92660', 'CA'),
#  (4, '95125', 'CA'),
#  (4, '92026', 'CA'),
#  (4, '92126', 'CA'),
#  (4, '90034', 'CA'),
#  (4, '95608', 'CA'),
#  (4, '94965', 'CA'),
#  (3, '92603', 'CA'),
#  (3, '93907', 'CA'),
#  (3, '92646', 'CA'),
#  (3, '95032', 'CA'),
#  (3, '94551', 'CA'),
#  (3, '94568', 'CA'),
#  (3, '92037', 'CA'),
#  (3, '92129', 'CA'),
#  (3, '94536', 'CA'),
#  (3, '94609', 'CA'),
#  (3, '93035', 'CA'),
#  (3, '95136', 'CA'),
#  (3, '95618', 'CA'),
#  (3, '95926', 'CA'),
#  (3, '90731', 'CA'),
#  (3, '95682', 'CA'),
#  (3, '95448', 'CA'),
#  (3, '94949', 'CA'),
#  (3, '90024', 'CA'),
#  (3, '93230', 'CA'),
#  (3, '92131', 'CA'),
#  (3, '93924', 'CA'),
#  (3, '91001', 'CA'),
#  (3, '93041', 'CA'),
#  (3, '92562', 'CA'),
#  (3, '92019', 'CA'),
#  (3, '95621', 'CA'),
#  (3, '92618', 'CA'),
#  (3, '94618', 'CA'),
#  (3, '91311', 'CA'),
#  (3, '91786', 'CA'),
#  (3, '94598', 'CA'),
#  (3, '94115', 'CA'),
#  (3, '90403', 'CA'),
#  (3, '94619', 'CA'),
#  (3, '91364', 'CA'),
#  (3, '94027', 'CA'),
#  (3, '93546', 'CA'),
#  (3, '93065', 'CA'),
#  (3, '95051', 'CA'),
#  (3, '93711', 'CA'),
#  (3, '95819', 'CA'),
#  (3, '92691', 'CA'),
#  (3, '92056', 'CA'),
#  (3, '93955', 'CA'),
#  (3, '92081', 'CA'),
#  (3, '92592', 'CA'),
#  (3, '95630', 'CA'),
#  (3, '92057', 'CA'),
#  (3, '91321', 'CA'),
#  (3, '94002', 'CA'),
#  (3, '95062', 'CA'),
#  (3, '92084', 'CA'),
#  (3, '94563', 'CA'),
#  (3, '90807', 'CA'),
#  (3, '94010', 'CA'),
#  (3, '94928', 'CA'),
#  (3, '92111', 'CA'),
#  (3, '91208', 'CA'),
#  (3, '90064', 'CA'),
#  (3, '95648', 'CA'),
#  (3, '92629', 'CA'),
#  (3, '94705', 'CA'),
#  (3, '91403', 'CA'),
#  (3, '92008', 'CA'),
#  (3, '92115', 'CA'),
#  (3, '94607', 'CA'),
#  (3, '90065', 'CA'),
#  (3, '92867', 'CA'),
#  (3, '91101', 'CA'),
#  (3, '95492', 'CA'),
#  (2, '94534', 'CA'),
#  (2, '94608', 'CA'),
#  (2, '95843', 'CA'),
#  (2, '94015', 'CA'),
#  (2, '90066', 'CA'),
#  (2, '90813', 'CA'),
#  (2, '95437', 'CA'),
#  (2, '92065', 'CA'),
#  (2, '94707', 'CA'),
#  (2, '91335', 'CA'),
#  (2, '92010', 'CA'),
#  (2, '94515', 'CA'),
#  (2, '91104', 'CA'),
#  (2, '91607', 'CA'),
#  (2, '92673', 'CA'),
#  (2, '95110', 'CA'),
#  (2, '93401', 'CA'),
#  (2, '95134', 'CA'),
#  (2, '92606', 'CA'),
#  (2, '91302', 'CA'),
#  (2, '93908', 'CA'),
#  (2, '95678', 'CA'),
#  (2, '92647', 'CA'),
#  (2, '95033', 'CA'),
#  (2, '94553', 'CA'),
#  (2, '91354', 'CA'),
#  (2, '91105', 'CA'),
#  (2, '95112', 'CA'),
#  (2, '92780', 'CA'),
#  (2, '93402', 'CA'),
#  (2, '94610', 'CA'),
#  (2, '93923', 'CA'),
#  (2, '94129', 'CA'),
#  (2, '94022', 'CA'),
#  (2, '90815', 'CA'),
#  (2, '92880', 'CA'),
#  (2, '93036', 'CA'),
#  (2, '91355', 'CA'),
#  (2, '92104', 'CA'),
#  (2, '91423', 'CA'),
#  (2, '92014', 'CA'),
#  (2, '94519', 'CA'),
#  (2, '91106', 'CA'),
#  (2, '92782', 'CA'),
#  (2, '95620', 'CA'),
#  (2, '95005', 'CA'),
#  (2, '94539', 'CA'),
#  (2, '94024', 'CA'),
#  (2, '94070', 'CA'),
#  (2, '92270', 'CA'),
#  (2, '95816', 'CA'),
#  (2, '90402', 'CA'),
#  (2, '92120', 'CA'),
#  (2, '92881', 'CA'),
#  (2, '94132', 'CA'),
#  (2, '90045', 'CA'),
#  (2, '90755', 'CA'),
#  (2, '93536', 'CA'),
#  (2, '95691', 'CA'),
#  (2, '93063', 'CA'),
#  (2, '95460', 'CA'),
#  (2, '92075', 'CA'),
#  (2, '92020', 'CA'),
#  (2, '94521', 'CA'),
#  (2, '93422', 'CA'),
#  (2, '95010', 'CA'),
#  (2, '92054', 'CA'),
#  (2, '94133', 'CA'),
#  (2, '95959', 'CA'),
#  (2, '94502', 'CA'),
#  (2, '90272', 'CA'),
#  (2, '92653', 'CA'),
#  (2, '94559', 'CA'),
#  (2, '94582', 'CA'),
#  (2, '94954', 'CA'),
#  (2, '91502', 'CA'),
#  (2, '91730', 'CA'),
#  (2, '94116', 'CA'),
#  (2, '93291', 'CA'),
#  (2, '91945', 'CA'),
#  (2, '90012', 'CA'),
#  (2, '92373', 'CA'),
#  (2, '94920', 'CA'),
#  (2, '91505', 'CA'),
#  (2, '92123', 'CA'),
#  (2, '94526', 'CA'),
#  (2, '90029', 'CA'),
#  (2, '92626', 'CA'),
#  (2, '93010', 'CA'),
#  (2, '94158', 'CA'),
#  (2, '92003', 'CA'),
#  (2, '94041', 'CA'),
#  (2, '94505', 'CA'),
#  (2, '94089', 'CA'),
#  (2, '95695', 'CA'),
#  (2, '92657', 'CA'),
#  (2, '92110', 'CA'),
#  (2, '94960', 'CA'),
#  (2, '95354', 'CA'),
#  (2, '92124', 'CA'),
#  (2, '91207', 'CA'),
#  (2, '90503', 'CA'),
#  (2, '92694', 'CA'),
#  (2, '93308', 'CA'),
#  (2, '95124', 'CA'),
#  (2, '92835', 'CA'),
#  (2, '93444', 'CA'),
#  (2, '96161', 'CA'),
#  (2, '92627', 'CA'),
#  (2, '95409', 'CA'),
#  (2, '94301', 'CA'),
#  (2, '91387', 'CA'),
#  (2, '95065', 'CA'),
#  (2, '94564', 'CA'),
#  (2, '94530', 'CA'),
#  (2, '93309', 'CA'),
#  (2, '90808', 'CA'),
#  (2, 'N/A', 'CA'),
#  (2, '93013', 'CA'),
#  (2, '94930', 'CA'),
#  (2, '94507', 'CA'),
#  (2, '91604', 'CA'),
#  (2, '93110', 'CA'),
#  (2, '95070', 'CA'),
#  (2, '95482', 'CA'),
#  (2, '95835', 'CA'),
#  (2, '90638', 'CA'),
#  (2, '96022', 'CA'),
#  (2, '95030', 'CA'),
#  (2, '94566', 'CA'),
#  (2, '94939', 'CA'),
#  (2, '91606', 'CA'),
#  (2, '92506', 'CA'),
#  (1, '95132', 'CA'),
#  (1, '95610', 'CA'),
#  (1, '94966', 'CA'),
#  (1, '95361', 'CA'),
#  (1, '92028', 'CA'),
#  (1, '91764', 'CA'),
#  (1, '90704', 'CA'),
#  (1, '92707', 'CA'),
#  (1, '93312', 'CA'),
#  (1, '96067', 'CA'),
#  (1, '92869', 'CA'),
#  (1, '93452', 'CA'),
#  (1, '95677', 'CA'),
#  (1, '92260', 'CA'),
#  (1, '91910', 'CA'),
#  (1, '94591', 'CA'),
#  (1, '93619', 'CA'),
#  (1, '90019', 'CA'),
#  (1, '93150', 'CA'),
#  (1, '95501', 'CA'),
#  (1, '92102', 'CA'),
#  (1, '92516', 'CA'),
#  (1, '94970', 'CA'),
#  (1, '95366', 'CA'),
#  (1, '91770', 'CA'),
#  (1, '95864', 'CA'),
#  (1, '90041', 'CA'),
#  (1, '92708', 'CA'),
#  (1, '94018', 'CA'),
#  (1, '94402', 'CA'),
#  (1, '96073', 'CA'),
#  (1, '90067', 'CA'),
#  (1, '90814', 'CA'),
#  (1, '92870', 'CA'),
#  (1, '93458', 'CA'),
#  (1, '90242', 'CA'),
#  (1, '95442', 'CA'),
#  (1, '92262', 'CA'),
#  (1, '94708', 'CA'),
#  (1, '91913', 'CA'),
#  (1, '94571', 'CA'),
#  (1, '94947', 'CA'),
#  (1, '91411', 'CA'),
#  (1, '92011', 'CA'),
#  (1, '94518', 'CA'),
#  (1, '94595', 'CA'),
#  (1, '91701', 'CA'),
#  (1, '93637', 'CA'),
#  (1, '95765', 'CA'),
#  (1, '90020', 'CA'),
#  (1, '90293', 'CA'),
#  (1, '92675', 'CA'),
#  (1, '93225', 'CA'),
#  (1, '95503', 'CA'),
#  (1, '92545', 'CA'),
#  (1, '92118', 'CA'),
#  (1, '92610', 'CA'),
#  (1, '95383', 'CA'),
#  (1, '92038', 'CA'),
#  (1, '94538', 'CA'),
#  (1, '91303', 'CA'),
#  (1, '91775', 'CA'),
#  (1, '90042', 'CA'),
#  (1, '96104', 'CA'),
#  (1, '93463', 'CA'),
#  (1, '94063', 'CA'),
#  (1, '90247', 'CA'),
#  (1, '92648', 'CA'),
#  (1, '95037', 'CA'),
#  (1, '92263', 'CA'),
#  (1, '94555', 'CA'),
#  (1, '94709', 'CA'),
#  (1, '91921', 'CA'),
#  (1, '92549', 'CA'),
#  (1, '94574', 'CA'),
#  (1, '94596', 'CA'),
#  (1, '91702', 'CA'),
#  (1, '93643', 'CA'),
#  (1, '94112', 'CA'),
#  (1, '95811', 'CA'),
#  (1, '90401', 'CA'),
#  (1, '95113', 'CA'),
#  (1, '95519', 'CA'),
#  (1, '93405', 'CA'),
#  (1, '95138', 'CA'),
#  (1, '92119', 'CA'),
#  (1, '92040', 'CA'),
#  (1, '91776', 'CA'),
#  (1, '95945', 'CA'),
#  (1, '90043', 'CA'),
#  (1, '90740', 'CA'),
#  (1, '91931', 'CA'),
#  (1, '94404', 'CA'),
#  (1, '93534', 'CA'),
#  (1, '95688', 'CA'),
#  (1, '95046', 'CA'),
#  (1, '95457', 'CA'),
#  (1, '92072', 'CA'),
#  (1, '94556', 'CA'),
#  (1, '91356', 'CA'),
#  (1, '92105', 'CA'),
#  (1, '94577', 'CA'),
#  (1, '94951', 'CA'),
#  (1, '91436', 'CA'),
#  (1, '94520', 'CA'),
#  (1, '91201', 'CA'),
#  (1, '91711', 'CA'),
#  (1, '93654', 'CA'),
#  (1, '92683', 'CA'),
#  (1, '93243', 'CA'),
#  (1, '95116', 'CA'),
#  (1, '95536', 'CA'),
#  (1, '92806', 'CA'),
#  (1, '93420', 'CA'),
#  (1, '95212', 'CA'),
#  (1, '96107', 'CA'),
#  (1, '92046', 'CA'),
#  (1, '92143', 'CA'),
#  (1, '94542', 'CA'),
#  (1, '95949', 'CA'),
#  (1, '91361', 'CA'),
#  (1, '90071', 'CA'),
#  (1, '91006', 'CA'),
#  (1, '94080', 'CA'),
#  (1, '92651', 'CA'),
#  (1, '95050', 'CA'),
#  (1, '92307', 'CA'),
#  (1, '92586', 'CA'),
#  (1, '94580', 'CA'),
#  (1, '91501', 'CA'),
#  (1, '91203', 'CA'),
#  (1, '91723', 'CA'),
#  (1, '93710', 'CA'),
#  (1, '92688', 'CA'),
#  (1, '93257', 'CA'),
#  (1, '95119', 'CA'),
#  (1, '95540', 'CA'),
#  (1, '92807', 'CA'),
#  (1, '95227', 'CA'),
#  (1, '95624', 'CA'),
#  (1, '96141', 'CA'),
#  (1, '92620', 'CA'),
#  (1, '92163', 'CA'),
#  (1, '94544', 'CA'),
#  (1, '91316', 'CA'),
#  (1, '91789', 'CA'),
#  (1, '93953', 'CA'),
#  (1, '90077', 'CA'),
#  (1, '91011', 'CA'),
#  (1, '94086', 'CA'),
#  (1, '95692', 'CA'),
#  (1, '90005', 'CA'),
#  (1, '95465', 'CA'),
#  (1, '92320', 'CA'),
#  (1, '92590', 'CA'),
#  (1, '92021', 'CA'),
#  (1, '94599', 'CA'),
#  (1, '91204', 'CA'),
#  (1, '95120', 'CA'),
#  (1, '95570', 'CA'),
#  (1, '90048', 'CA'),
#  (1, '90804', 'CA'),
#  (1, '92821', 'CA'),
#  (1, '93428', 'CA'),
#  (1, '95628', 'CA'),
#  (1, '96145', 'CA'),
#  (1, '92625', 'CA'),
#  (1, '95405', 'CA'),
#  (1, '94545', 'CA'),
#  (1, '94702', 'CA'),
#  (1, '91791', 'CA'),
#  (1, '94134', 'CA'),
#  (1, '95965', 'CA'),
#  (1, '94503', 'CA'),
#  (1, '91016', 'CA'),
#  (1, '93549', 'CA'),
#  (1, '94087', 'CA'),
#  (1, '95694', 'CA'),
#  (1, '95060', 'CA'),
#  (1, '95470', 'CA'),
#  (1, '94560', 'CA'),
#  (1, '94955', 'CA'),
#  (1, '95236', 'CA'),
#  (1, '91205', 'CA'),
#  (1, '91737', 'CA'),
#  (1, '93720', 'CA'),
#  (1, '95831', 'CA'),
#  (1, '92692', 'CA'),
#  (1, '93292', 'CA'),
#  (1, '95123', 'CA'),
#  (1, '95602', 'CA'),
#  (1, '96001', 'CA'),
#  (1, '90806', 'CA'),
#  (1, '92831', 'CA'),
#  (1, '93443', 'CA'),
#  (1, '96151', 'CA'),
#  (1, '95018', 'CA'),
#  (1, '92223', 'CA'),
#  (1, '94546', 'CA'),
#  (1, '91801', 'CA'),
#  (1, '91377', 'CA'),
#  (1, '93550', 'CA'),
#  (1, '90014', 'CA'),
#  (1, '92374', 'CA'),
#  (1, '94925', 'CA'),
#  (1, '95603', 'CA'),
#  (1, '92593', 'CA'),
#  (1, '94585', 'CA'),
#  (1, '91602', 'CA'),
#  (1, '92025', 'CA'),
#  (1, '94528', 'CA'),
#  (1, '94605', 'CA'),
#  (1, '91748', 'CA'),
#  (1, '93722', 'CA'),
#  (1, '95833', 'CA'),
#  (1, '90031', 'CA'),
#  (1, '96002', 'CA'),
#  (1, '90051', 'CA'),
#  (1, '95633', 'CA'),
#  (1, '95020', 'CA'),
#  (1, '92058', 'CA'),
#  (1, '92232', 'CA'),
#  (1, '94547', 'CA'),
#  (1, '94704', 'CA'),
#  (1, '91324', 'CA'),
#  (1, '91901', 'CA'),
#  (1, '92007', 'CA'),
#  (1, '94043', 'CA'),
#  (1, '91041', 'CA'),
#  (1, '94102', 'CA'),
#  (1, '95722', 'CA'),
#  (1, '90015', 'CA'),
#  (1, '93108', 'CA'),
#  (1, '92091', 'CA'),
#  (1, '92503', 'CA'),
#  (1, '95605', 'CA'),
#  (1, '92595', 'CA'),
#  (1, '94963', 'CA'),
#  (1, '95355', 'CA'),
#  (1, '94606', 'CA'),
#  (1, '91750', 'CA'),
#  (1, '93726', 'CA'),
#  (1, '95834', 'CA'),
#  (1, '90504', 'CA'),
#  (1, '92701', 'CA'),
#  (1, '96003', 'CA'),
#  (1, '92865', 'CA'),
#  (1, '93446', 'CA'),
#  (1, '95023', 'CA'),
#  (1, '95425', 'CA'),
#  (1, '92059', 'CA'),
#  (1, '92247', 'CA'),
#  (1, '91325', 'CA'),
#  (1, '91902', 'CA'),
#  (1, '94011', 'CA'),
#  (1, '94303', 'CA'),
#  (1, '94044', 'CA'),
#  (1, '94588', 'CA'),
#  (1, '90230', 'CA'),
#  (1, '91042', 'CA'),
#  (1, '93562', 'CA'),
#  (1, '94103', 'CA'),
#  (1, '95746', 'CA'),
#  (1, '90016', 'CA'),
#  (1, '90290', 'CA'),
#  (1, '92663', 'CA'),
#  (1, '92092', 'CA'),
#  (1, '92504', 'CA'),
#  (1, '94565', 'CA'),
#  (1, '95128', 'CA'),
#  (1, '92602', 'CA'),
#  (1, '95356', 'CA'),
#  (1, '92027', 'CA'),
#  (1, '92127', 'CA'),
#  (1, '94531', 'CA'),
#  (1, '91214', 'CA'),
#  (1, '91755', 'CA'),
#  (1, '93730', 'CA'),
#  (1, '94122', 'CA'),
#  (1, '92705', 'CA'),
#  (1, '93311', 'CA'),
#  (1, '90810', 'CA'),
#  (1, '93447', 'CA'),
#  (1, '95650', 'CA'),
#  (1, '92637', 'CA'),
#  (1, '93021', 'CA'),
#  (1, '95436', 'CA'),
#  (1, '92253', 'CA'),
#  (1, '91326', 'CA'),
#  (1, '91908', 'CA'),
#  (1, '94014', 'CA'),
#  (1, '94304', 'CA'),
#  (1, '91405', 'CA'),
#  (1, '94590', 'CA'),
#  (1, '93611', 'CA'),
#  (1, '95747', 'CA'),
#  (1, '90017', 'CA'),
#  (1, '93117', 'CA'),
#  (1, '95076', 'CA'),
#  (10, '80304', 'CO'),
#  (9, '80210', 'CO'),
#  (7, '80303', 'CO'),
#  (7, '80526', 'CO'),
#  (6, '80220', 'CO'),
#  (6, '80403', 'CO'),
#  (5, '80126', 'CO'),
#  (5, '80206', 'CO'),
#  (5, '80227', 'CO'),
#  (5, '80401', 'CO'),
#  (5, '80205', 'CO'),
#  (4, '80521', 'CO'),
#  (4, '80021', 'CO'),
#  (4, '81620', 'CO'),
#  (4, '80127', 'CO'),
#  (4, '80111', 'CO'),
#  (4, '80128', 'CO'),
#  (4, '80026', 'CO'),
#  (4, '80132', 'CO'),
#  (4, '80211', 'CO'),
#  (4, '80134', 'CO'),
#  (4, '80922', 'CO'),
#  (4, '80237', 'CO'),
#  (4, '81601', 'CO'),
#  (4, '80439', 'CO'),
#  (4, '80020', 'CO'),
#  (3, '80904', 'CO'),
#  (3, '80906', 'CO'),
#  (3, '80302', 'CO'),
#  (3, '80525', 'CO'),
#  (3, '80212', 'CO'),
#  (3, '80503', 'CO'),
#  (3, '80014', 'CO'),
#  (3, '80015', 'CO'),
#  (2, '81611', 'CO'),
#  (2, '80247', 'CO'),
#  (2, '80222', 'CO'),
#  (2, '80004', 'CO'),
#  (2, '80301', 'CO'),
#  (2, '80524', 'CO'),
#  (2, '80005', 'CO'),
#  (2, '80908', 'CO'),
#  (2, '81623', 'CO'),
#  (2, '80112', 'CO'),
#  (2, '80129', 'CO'),
#  (2, '80113', 'CO'),
#  (2, '80917', 'CO'),
#  (2, '80027', 'CO'),
#  (2, '80918', 'CO'),
#  (2, '81301', 'CO'),
#  (2, '80120', 'CO'),
#  (2, '80919', 'CO'),
#  (2, '80138', 'CO'),
#  (2, '80214', 'CO'),
#  (2, '81501', 'CO'),
#  (2, '80234', 'CO'),
#  (2, '80827', 'CO'),
#  (2, '80923', 'CO'),
#  (2, '80203', 'CO'),
#  (2, '80218', 'CO'),
#  (2, '80238', 'CO'),
#  (1, '80547', 'CO'),
#  (1, '80108', 'CO'),
#  (1, '80002', 'CO'),
#  (1, '81131', 'CO'),
#  (1, '80602', 'CO'),
#  (1, '80109', 'CO'),
#  (1, '80465', 'CO'),
#  (1, '81201', 'CO'),
#  (1, '80207', 'CO'),
#  (1, '80022', 'CO'),
#  (1, '81621', 'CO'),
#  (1, '80223', 'CO'),
#  (1, '80631', 'CO'),
#  (1, '80466', 'CO'),
#  (1, '81235', 'CO'),
#  (1, '80209', 'CO'),
#  (1, '80023', 'CO'),
#  (1, '80226', 'CO'),
#  (1, '80634', 'CO'),
#  (1, '80487', 'CO'),
#  (1, '80010', 'CO'),
#  (1, '80911', 'CO'),
#  (1, '81236', 'CO'),
#  (1, '81625', 'CO'),
#  (1, '80643', 'CO'),
#  (1, '80488', 'CO'),
#  (1, '80011', 'CO'),
#  (1, '81252', 'CO'),
#  (1, '80527', 'CO'),
#  (1, '81639', 'CO'),
#  (1, '80228', 'CO'),
#  (1, '80644', 'CO'),
#  (1, '80116', 'CO'),
#  (1, '80498', 'CO'),
#  (1, '80012', 'CO'),
#  (1, '80308', 'CO'),
#  (1, '80528', 'CO'),
#  (1, '80031', 'CO'),
#  (1, '81652', 'CO'),
#  (1, '80230', 'CO'),
#  (1, '80808', 'CO'),
#  (1, '80501', 'CO'),
#  (1, '80013', 'CO'),
#  (1, '81403', 'CO'),
#  (1, '80534', 'CO'),
#  (1, '80033', 'CO'),
#  (1, '80121', 'CO'),
#  (1, '80233', 'CO'),
#  (1, '80813', 'CO'),
#  (1, '80202', 'CO'),
#  (1, '80215', 'CO'),
#  (1, '80537', 'CO'),
#  (1, '80104', 'CO'),
#  (1, '80122', 'CO'),
#  (1, '80422', 'CO'),
#  (1, '80504', 'CO'),
#  (1, '81507', 'CO'),
#  (1, '80216', 'CO'),
#  (1, '80540', 'CO'),
#  (1, '80106', 'CO'),
#  (1, '80123', 'CO'),
#  (1, '80829', 'CO'),
#  (1, '80430', 'CO'),
#  (1, '80962', 'CO'),
#  (1, '80204', 'CO'),
#  (1, '80516', 'CO'),
#  (1, '80016', 'CO'),
#  (1, '80542', 'CO'),
#  (1, '80107', 'CO'),
#  (1, '80124', 'CO'),
#  (1, '80000', 'CO'),
#  (1, '80864', 'CO'),
#  (1, '81007', 'CO'),
#  (1, '80517', 'CO'),
#  (8, '6880', 'CT'),
#  (6, '6824', 'CT'),
#  (6, '6840', 'CT'),
#  (5, '6820', 'CT'),
#  (5, '6614', 'CT'),
#  (4, '6107', 'CT'),
#  (4, '6109', 'CT'),
#  (4, '6902', 'CT'),
#  (3, '6410', 'CT'),
#  (3, '6517', 'CT'),
#  (3, '6851', 'CT'),
#  (3, '6484', 'CT'),
#  (3, '6117', 'CT'),
#  (3, '6371', 'CT'),
#  (3, '6903', 'CT'),
#  (3, '6489', 'CT'),
#  (3, '6905', 'CT'),
#  (3, '6877', 'CT'),
#  (2, '6405', 'CT'),
#  (2, '6033', 'CT'),
#  (2, '6883', 'CT'),
#  (2, '6415', 'CT'),
#  (2, '6830', 'CT'),
#  (2, '6035', 'CT'),
#  (2, '6762', 'CT'),
#  (2, '6416', 'CT'),
#  (2, '6340', 'CT'),
#  (2, '6776', 'CT'),
#  (2, '6040', 'CT'),
#  (2, '6478', 'CT'),
#  (2, '6777', 'CT'),
#  (2, '6422', 'CT'),
#  (2, '6480', 'CT'),
#  (2, '6853', 'CT'),
#  (2, '6798', 'CT'),
#  (2, '6001', 'CT'),
#  (2, '6854', 'CT'),
#  (2, '6010', 'CT'),
#  (2, '6073', 'CT'),
#  ...]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# select count(distinct user_guid) as unique_id, state, zip from users
# where country = "US"
# group by state, zip
# having count(user_guid) >= 5
# order by state asc, unique_id desc
# Out:
# 377 rows affected.
# [(14, 'AZ', '86303'),
#  (6, 'AZ', '85718'),
#  (5, 'AZ', '85253'),
#  (5, 'AZ', '85254'),
#  (5, 'AZ', '85260'),
#  (5, 'AZ', '85711'),
#  (5, 'AZ', '85749'),
#  (4, 'AZ', '85750'),
#  (3, 'AZ', '85032'),
#  (16, 'CA', '92107'),
#  (13, 'CA', '90046'),
#  (12, 'CA', '94107'),
#  (12, 'CA', '92130'),
#  (10, 'CA', '94110'),
#  (10, 'CA', '92024'),
#  (9, 'CA', '94941'),
#  (9, 'CA', '94611'),
#  (9, 'CA', '94114'),
#  (9, 'CA', '94025'),
#  (8, 'CA', '92064'),
#  (8, 'CA', '90068'),
#  (8, 'CA', '94131'),
#  (8, 'CA', '90069'),
#  (8, 'CA', '90049'),
#  (7, 'CA', '94121'),
#  (7, 'CA', '90291'),
#  (7, 'CA', '90292'),
#  (7, 'CA', '90266'),
#  (7, 'CA', '90803'),
#  (7, 'CA', '93003'),
#  (7, 'CA', '94602'),
#  (7, 'CA', '94117'),
#  (7, 'CA', '90278'),
#  (6, 'CA', '94549'),
#  (6, 'CA', '90036'),
#  (6, 'CA', '94061'),
#  (6, 'CA', '92672'),
#  (6, 'CA', '91301'),
#  (6, 'CA', '94123'),
#  (6, 'CA', '90039'),
#  (6, 'CA', '95762'),
#  (6, 'CA', '92103'),
#  (6, 'CA', '92071'),
#  (6, 'CA', '94901'),
#  (6, 'CA', '95008'),
#  (6, 'CA', '94903'),
#  (6, 'CA', '94952'),
#  (6, 'CA', '95014'),
#  (6, 'CA', '90274'),
#  (6, 'CA', '90277'),
#  (5, 'CA', '94550'),
#  (5, 'CA', '94706'),
#  (5, 'CA', '92009'),
#  (5, 'CA', '94510'),
#  (5, 'CA', '90232'),
#  (5, 'CA', '92101'),
#  (5, 'CA', '93023'),
#  (5, 'CA', '91406'),
#  (5, 'CA', '94109'),
#  (5, 'CA', '95003'),
#  (5, 'CA', '94597'),
#  (5, 'CA', '90025'),
#  (5, 'CA', '93940'),
#  (5, 'CA', '95818'),
#  (5, 'CA', '92106'),
#  (5, 'CA', '92122'),
#  (5, 'CA', '94904'),
#  (5, 'CA', '92211'),
#  (5, 'CA', '94040'),
#  (5, 'CA', '90210'),
#  (5, 'CA', '90405'),
#  (5, 'CA', '93105'),
#  (5, 'CA', '94118'),
#  (5, 'CA', '93012'),
#  (5, 'CA', '95476'),
#  (4, 'CA', '92026'),
#  (4, 'CA', '95608'),
#  (4, 'CA', '94306'),
#  (4, 'CA', '92117'),
#  (4, 'CA', '90720'),
#  (4, 'CA', '95616'),
#  (4, 'CA', '94062'),
#  (4, 'CA', '95401'),
#  (4, 'CA', '90265'),
#  (4, 'CA', '90026'),
#  (4, 'CA', '92886'),
#  (4, 'CA', '95404'),
#  (4, 'CA', '92078'),
#  (4, 'CA', '91942'),
#  (4, 'CA', '90027'),
#  (4, 'CA', '92656'),
#  (4, 'CA', '94703'),
#  (4, 'CA', '90211'),
#  (4, 'CA', '93561'),
#  (3, 'CA', '90065'),
#  (3, 'CA', '91001'),
#  (3, 'CA', '92081'),
#  (3, 'CA', '92057'),
#  (10, 'CO', '80304'),
#  (9, 'CO', '80210'),
#  (7, 'CO', '80303'),
#  (7, 'CO', '80526'),
#  (6, 'CO', '80220'),
#  (6, 'CO', '80403'),
#  (5, 'CO', '80205'),
#  (5, 'CO', '80126'),
#  (5, 'CO', '80206'),
#  (5, 'CO', '80227'),
#  (5, 'CO', '80401'),
#  (4, 'CO', '80237'),
#  (4, 'CO', '80020'),
#  (4, 'CO', '80021'),
#  (4, 'CO', '80127'),
#  (4, 'CO', '80128'),
#  (4, 'CO', '80134'),
#  (8, 'CT', '6880'),
#  (6, 'CT', '6824'),
#  (6, 'CT', '6840'),
#  (5, 'CT', '6614'),
#  (5, 'CT', '6820'),
#  (14, 'DC', '20009'),
#  (8, 'DC', '20002'),
#  (8, 'DC', '20007'),
#  (7, 'DC', '20001'),
#  (7, 'DC', '20016'),
#  (6, 'DC', '20011'),
#  (6, 'DC', '20005'),
#  (5, 'DC', '20003'),
#  (7, 'DE', '19958'),
#  (6, 'FL', '33647'),
#  (6, 'FL', '33418'),
#  (6, 'FL', '32312'),
#  (5, 'FL', '32751'),
#  (5, 'FL', '32765'),
#  (5, 'FL', '33156'),
#  (4, 'FL', '32566'),
#  (4, 'FL', '34698'),
#  (4, 'FL', '33435'),
#  (4, 'FL', '33477'),
#  (4, 'FL', '33139'),
#  (4, 'FL', '34134'),
#  (3, 'FL', '33312'),
#  (2, 'FL', '32821'),
#  (7, 'GA', '30305'),
#  (7, 'GA', '30004'),
#  (6, 'GA', '30345'),
#  (5, 'GA', '30316'),
#  (5, 'GA', '30067'),
#  (5, 'GA', '30308'),
#  (5, 'GA', '30328'),
#  (8, 'HI', '96734'),
#  (9, 'ID', '83702'),
#  (18, 'IL', '60614'),
#  (11, 'IL', '60654'),
#  (9, 'IL', '60657'),
#  (9, 'IL', '60640'),
#  (8, 'IL', '60613'),
#  (7, 'IL', '60610'),
#  (7, 'IL', '60660'),
#  (6, 'IL', '60618'),
#  (6, 'IL', '60647'),
#  (5, 'IL', '60626'),
#  (5, 'IL', '60093'),
#  (5, 'IL', '60642'),
#  (4, 'IL', '60201'),
#  (6, 'IN', '47401'),
#  (6, 'KS', '66062'),
#  (4, 'KY', '41017'),
#  (3, 'KY', '40222'),
#  (8, 'LA', '70115'),
#  (6, 'LA', '70118'),
#  (8, 'MA', '2127'),
#  (6, 'MA', '2129'),
#  (5, 'MA', '2143'),
#  (5, 'MA', '2130'),
#  (5, 'MA', '2116'),
#  (5, 'MA', '2472'),
#  (5, 'MA', '2135'),
#  (8, 'MD', '20854'),
#  (7, 'MD', '20817'),
#  (7, 'MD', '20910'),
#  (6, 'MD', '21286'),
#  (6, 'MD', '20878'),
#  (5, 'MD', '20895'),
#  (5, 'MD', '21228'),
#  (5, 'MD', '21230'),
#  (5, 'MD', '20852'),
#  (4, 'MD', '21044'),
#  (8, 'MI', '48103'),
#  (4, 'MI', '48105'),
#  (2, 'MI', '48307'),
#  (6, 'MN', '55426'),
#  (6, 'MO', '63139'),
#  (5, 'MO', '63122'),
#  (5, 'MT', '59715'),
#  (83, 'N/A', 'N/A'),
#  (32, 'NC', '27701'),
#  (26, 'NC', '27705'),
#  (17, 'NC', '27516'),
#  (17, 'NC', '27707'),
#  (11, 'NC', '27613'),
#  (11, 'NC', '27517'),
#  (11, 'NC', '27615'),
#  (10, 'NC', '27713'),
#  (9, 'NC', '27539'),
#  (9, 'NC', '27617'),
#  (9, 'NC', '27278'),
#  (9, 'NC', '27514'),
#  (7, 'NC', '27614'),
#  (7, 'NC', '27519'),
#  (7, 'NC', '27608'),
#  (7, 'NC', '27609'),
#  (7, 'NC', '27513'),
#  (6, 'NC', '27612'),
#  (6, 'NC', '27410'),
#  (6, 'NC', '27603'),
#  (6, 'NC', '28787'),
#  (6, 'NC', '27607'),
#  (6, 'NC', '28374'),
#  (6, 'NC', '28270'),
#  (6, 'NC', '27104'),
#  (6, 'NC', '27587'),
#  (5, 'NC', '27502'),
#  (5, 'NC', '27606'),
#  (5, 'NC', '28226'),
#  (5, 'NC', '28205'),
#  (4, 'NC', '28027'),
#  (4, 'NC', '27616'),
#  (4, 'NC', '27511'),
#  (4, 'NC', '28387'),
#  (4, 'NC', '27106'),
#  (3, 'NC', '28277'),
#  (3, 'NC', '28025'),
#  (3, 'NC', '28734'),
#  (3, 'NH', '3290'),
#  (8, 'NJ', '7030'),
#  (7, 'NJ', '7302'),
#  (5, 'NJ', '8540'),
#  (3, 'NJ', '8758'),
#  (3, 'NJ', '7931'),
#  (6, 'NM', '87111'),
#  (5, 'NV', '89511'),
#  (14, 'NY', '10003'),
#  (13, 'NY', '10023'),
#  (13, 'NY', '10024'),
#  (12, 'NY', '11201'),
#  (12, 'NY', '10025'),
#  (11, 'NY', '10028'),
#  (10, 'NY', '10016'),
#  (9, 'NY', '10019'),
#  (9, 'NY', '10011'),
#  (8, 'NY', '10021'),
#  (8, 'NY', '14850'),
#  (8, 'NY', '11238'),
#  (8, 'NY', '10014'),
#  (7, 'NY', '11249'),
#  (6, 'NY', '11217'),
#  (6, 'NY', '10128'),
#  (6, 'NY', '10583'),
#  (6, 'NY', '10012'),
#  (6, 'NY', '10013'),
#  (5, 'NY', '11105'),
#  (5, 'NY', '10075'),
#  (5, 'NY', '10708'),
#  (5, 'NY', '11222'),
#  (5, 'NY', '10022'),
#  (5, 'NY', '11209'),
#  (5, 'NY', '11211'),
#  (5, 'NY', '11215'),
#  (4, 'NY', '10803'),
#  (4, 'NY', '10514'),
#  (4, 'NY', '10001'),
#  (8, 'OH', '43214'),
#  (5, 'OH', '43068'),
#  (5, 'OH', '45040'),
#  (5, 'OH', '44149'),
#  (5, 'OH', '43235'),
#  (5, 'OH', '45243'),
#  (5, 'OK', '73013'),
#  (4, 'OK', '73112'),
#  (8, 'OR', '97229'),
#  (7, 'OR', '97212'),
#  (5, 'OR', '97702'),
#  (5, 'OR', '97215'),
#  (5, 'OR', '97405'),
#  (5, 'OR', '97206'),
#  (4, 'OR', '97701'),
#  (4, 'OR', '97239'),
#  (4, 'OR', '97203'),
#  (6, 'PA', '19087'),
#  (6, 'PA', '19460'),
#  (6, 'PA', '19147'),
#  (5, 'PA', '15237'),
#  (5, 'PA', '15101'),
#  (4, 'PA', '16066'),
#  (3, 'PA', '15215'),
#  (3, 'PA', '19335'),
#  (3, 'PA', '17011'),
#  (1, 'PA', '16052'),
#  (14, 'SC', '29303'),
#  (13, 'SC', '29464'),
#  (5, 'SC', '29407'),
#  (5, 'SC', '29707'),
#  (5, 'SC', '29205'),
#  (4, 'SC', '29455'),
#  (7, 'TN', '37205'),
#  (6, 'TN', '37027'),
#  (6, 'TN', '37067'),
#  (4, 'TN', '37215'),
#  (3, 'TN', '37128'),
#  (2, 'TN', '37204'),
#  (8, 'TX', '78750'),
#  (8, 'TX', '78745'),
#  (8, 'TX', '77008'),
#  (7, 'TX', '78703'),
#  (7, 'TX', '77007'),
#  (6, 'TX', '78704'),
#  (6, 'TX', '77584'),
#  (6, 'TX', '78757'),
#  (5, 'TX', '75248'),
#  (5, 'TX', '78748'),
#  (5, 'TX', '76712'),
#  (5, 'TX', '75219'),
#  (5, 'TX', '77381'),
#  (5, 'TX', '77382'),
#  (5, 'TX', '75023'),
#  (5, 'TX', '78613'),
#  (5, 'TX', '75025'),
#  (5, 'TX', '77006'),
#  (4, 'TX', '78660'),
#  (4, 'TX', '78723'),
#  (4, 'TX', '77546'),
#  (4, 'TX', '75214'),
#  (3, 'TX', '75022'),
#  (6, 'UT', '84098'),
#  (4, 'UT', '84109'),
#  (4, 'UT', '84093'),
#  (9, 'VA', '22201'),
#  (9, 'VA', '20191'),
#  (8, 'VA', '22314'),
#  (7, 'VA', '22903'),
#  (7, 'VA', '22043'),
#  (7, 'VA', '20147'),
#  (6, 'VA', '20120'),
#  (6, 'VA', '22101'),
#  (6, 'VA', '22304'),
#  (5, 'VA', '23462'),
#  (5, 'VA', '22301'),
#  (5, 'VA', '22902'),
#  (4, 'VA', '22030'),
#  (4, 'VA', '23185'),
#  (4, 'VA', '20170'),
#  (4, 'VA', '20176'),
#  (4, 'VA', '20148'),
#  (2, 'VA', '22602'),
#  (2, 'VA', '23435'),
#  (2, 'VA', '20105'),
#  (9, 'WA', '98103'),
#  (7, 'WA', '98122'),
#  (7, 'WA', '98225'),
#  (7, 'WA', '98102'),
#  (7, 'WA', '98118'),
#  (6, 'WA', '98199'),
#  (6, 'WA', '98074'),
#  (6, 'WA', '98045'),
#  (6, 'WA', '98052'),
#  (6, 'WA', '98033'),
#  (6, 'WA', '98115'),
#  (5, 'WA', '98072'),
#  (5, 'WA', '98106'),
#  (5, 'WA', '98110'),
#  (4, 'WA', '98370'),
#  (4, 'WA', '98112'),
#  (4, 'WA', '98038'),
#  (5, 'WI', '53213'),
#  (4, 'WI', '53718'),
#  (4, 'WI', '53515')]

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
